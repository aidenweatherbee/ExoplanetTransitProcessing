# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Exoplanet Transit Guide</title>
#     <style>
#         h1, h2 {
#             color: skyblue;
#         }
#     </style>
# </head>
# <body>
#
# <h1>Exoplanet Transit Guide</h1>
#
# <h2>Section 0: Overview</h2>
# <p>
# I have broken down the process of capturing and processing an exoplanet transit into eight steps which are outlined below. This quick overview will help the reader understand the whole process before diving into the specific details of each step. If you are just working with the provided transit images then you can skip step 1.
# </p>
# <ul>
#     <li><a href="#selecting-a-transit">Section 1: Selecting a Transit</a> - This section describes 6 things to keep in mind when selecting a transit. It also provides some good resources for finding a suitable transit.</li>
#     <li><a href="#Loading-Images">Section 2: Loading Images</a></li>
#     <li><a href="#Flat/Bias-Correction">Section 3: Flat/Bias Correction</a></li>
#     <li><a href="#Aperture-Test">Section 4: Aperture Test</a></li>
#     <li><a href="#Star-Tracking">Section 5: Star Tracking</a></li>
#     <li><a href="#Differential-Photometry">Section 6: Differential Photometry</a></li>
#     <li><a href="#Plotting-Transit">Section 7: Plotting Transit</a></li>
#     <li><a href="#Estimating-Exoplanet-Information">Section 8: Estimating Exoplanet Information</a></li>
# </ul>

# %% [markdown]
# <h2 style="color: skyblue;" id="selecting-a-transit">Section 1: Selecting a Transit</h2>
# <p>
# When selecting the exoplanet transit the weather is of course important above all else. Clouds can cause a drop in brightness over 40% in my experience and when looking for a drop around 1% this can make it impossible to measure even with differential photometry. If you're using the York University observatory they provide a great resource for helping you choose a clear night for your transit but the data is only for the next 72 hours: <a href="https://www.cleardarksky.com/c/YrkUObONkey.html?1">York University Observatory Clear Sky Chart</a>. Once you have a clear night selected there are 5 main things to think about for selecting the specific transit:
# </p>
# <ol>
#     <li><strong>Stellar Magnitude</strong> - The brightness measurement. With the light collecting power of the 1 meter telescope the upper limit is around 15. Any less bright and the exposure times would likely be too long. If you find a transit around 14-15 Vmag you can look at the starfield by generating a starfield with the <a href="http://var2.astro.cz/ETD/predictions.php">Exoplanet Transit Database</a> to ensure there are no other really bright stars in the FOV. If this is the case you may be able to capture the transit with long exposure times.</li>
#     <li><strong>Transit Depth</strong> - Generally we want a drop in brightness around 1% or more in order to accurately extract the transit but a larger transit depth is always easier to detect.</li>
#     <li><strong>Transit Duration</strong> - The length of the transit is important because of telescope availability as well as finding a window of good weather. The shorter the transit the higher the chances of success.</li>
#     <li><strong>Transit Start Time</strong> - You need the transit to occur at night and ideally you want it to start at least 1 hour and 15 minutes after sunset (45 mins for twilight and 30 mins for a baseline before the transit). The <a href="https://www.cleardarksky.com/c/YrkUObONkey.html?1">York University Observatory Clear Sky Chart</a> has estimates for the brightness.</li>
#     <li><strong>Celestial Position</strong> - The following link can be used to ensure that your object is at least 20 degrees above the horizon from 30 minutes before to 30 minutes after the transit: <a href="http://catserver.ing.iac.es/staralt/index.php">STARALT</a></li>
# </ol>
# <p>
# The <a href="http://var2.astro.cz/ETD/predictions.php">Exoplanet Transit Database</a> is a great resource. With a given Lat and Long and date it will give you a list of confirmed transits that are visible from your location and more than 20 degrees above the horizon mid transit. It can also be used to make a finder chart so that you can identify which star is the transit star. It also includes all of the important information mentioned above. You can then input the given RA and Dec into <a href="http://catserver.ing.iac.es/staralt/index.php">STARALT</a></li> to confirm it is viewable for the entire transit.
# </p>

# %% [markdown]
# <h2 style="color: skyblue;" id="Loading-Images">Section 2: Loading Images</h2>
# <p>
#
#  After you download the images, you will be given the following:
#  <li> 20 bias frames, ex. "Bias_2x2-0001" </li>
#  <li>20 flat frames, ex. "Flat_R_2x2_0001" </li>
#  You will also be given the transit images, ex. "KOI-13_LIGHT_R_3s_BIN2_-10C_001_20240519_222732_343_PA36.04"
#
# Ensure that both your transit images and your Flat images you download contain the same filter, which should be red. This is indicated by the _ R _ in the names. The name of the transit images include the date and time the image was taken.
# </p>

# %%
import os
from astropy.io import fits
import matplotlib.pyplot as plt

def load_fits_images(folder_path, keyword):
    """
    Loads all fits images from a given folder that have the given keyword and stores the time the image was taken as well.
    ex: Flat_R to load flats images with the red filter
    """
    images = []
    
    for filename in os.listdir(folder_path):
        if keyword in filename:
            file_path = os.path.join(folder_path, filename)
            with fits.open(file_path) as hdul:
                image_data = hdul[0].data
                images.append({'data': image_data, 'filename': filename, 'header': hdul[0].header})

    if not images:
        raise FileNotFoundError(f"No FITS files with keyword '{keyword}' found in the folder '{folder_path}'")

    return images

# Example usage
folder = "D:\\TransitResearch\\2024-05-31\\HAT-P-27b"
keyword = "FLAT_R"
images = load_fits_images(folder, keyword)

# show the first image
plt.figure()
plt.imshow(images[0]['data'], cmap='gray')
plt.title('First Image')
plt.colorbar()
plt.show()

# clear memory of unneeded images
del images

# %% [markdown]
# <h2 style="color: skyblue;" id="Flat/Bias-Correction">Section 3: Flat/Bias Correction</h2>
# <p>
#
# ## Bias Frames
# These are images taken with the smallest exposure time possible (0.1s at the Yorku observatory) and the shutter closed so there is no light. They are used to correct for electric noise introduced during the readout proccess.
#
# ## Flat Frames ##
# These are images taken of a uniformly lit surface. At the Yorku observatory they are taken with a lamp pointed at the telescope dome. They are used to correct for the slightly different sensitivity of each pixel in the CCD camera. They also correct for any artifacts or dust in the optical path.
#
# ## Calibrating frames
# <ol>
# <li> Load the flat and bias frames. Create a single flat and single bias image by taking the average of the 20 images you are provided.</li>
# <li> Subtract the bias from all frames including the flat frame. </li>
# <li> divide the transit images by the flat frame to get your corrected frames. </li>
# </ol>
# </p>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from astropy.io import fits
from astropy.nddata import CCDData
import ccdproc
import astroalign as aa
from photutils import Background2D, MedianBackground

def calibrate_and_save_images(science_images, flat_images, bias_images, output_folder):
    """
    Calibrate science images using the provided flat and bias frames,
    apply advanced background subtraction, and save the calibrated images to the specified folder.
    """
    # Median combine the flat and bias frames
    flat_stack = np.array([img['data'] for img in flat_images])
    Flat = np.median(flat_stack, axis=0)
    bias_stack = np.array([img['data'] for img in bias_images])
    Bias = np.median(bias_stack, axis=0)
    # Normalize the flat field
    Flat = Flat / np.median(Flat)
    
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Use the first science image as the reference for alignment
    reference_image = science_images[0]['data']
    
    # Process each science image
    for science_image in science_images:
        try:
            # Convert the science image to CCDData object
            science_ccd = CCDData(science_image['data'], unit='adu')
            
            # Subtract bias
            science_ccd = ccdproc.subtract_bias(science_ccd, CCDData(Bias, unit='adu'))
            
            # Correct for flat field
            science_ccd = ccdproc.flat_correct(science_ccd, CCDData(Flat, unit='adu'))
            
            # Apply advanced background subtraction using photutils
            bkg_estimator = MedianBackground()
            bkg = Background2D(science_ccd.data, (50, 50), filter_size=(3, 3), bkg_estimator=bkg_estimator)
            science_ccd.data = science_ccd.data - bkg.background
            
            # Align images using astroalign
            aligned_image, _ = aa.register(science_ccd.data, reference_image)
            
            # Get the original filename, if available
            original_filename = science_image.get('filename', f"Calibrated_.fits")
            # Sanitize the filename by replacing colons with underscores
            sanitized_filename = original_filename.replace(":", "_")
            # Save the calibrated image to the output folder with the sanitized filename
            output_file = os.path.join(output_folder, sanitized_filename)
            # Create a new FITS HDU with the calibrated data
            hdu = fits.PrimaryHDU(aligned_image)
            # Copy the original header if available
            if 'header' in science_image:
                hdu.header = science_image['header']
            # Write the calibrated image to the output file
            hdu.writeto(output_file, overwrite=True)
            
            print(f"Successfully calibrated and aligned {original_filename}")
            
        except Exception as e:
            print(f"Failed to process {science_image['filename']}: {e}")
            continue
        
    # Display the calibrated flat image
    plt.figure()
    plt.imshow(Flat, cmap='gray')
    plt.title('Calibrated Flat Image')
    plt.colorbar()
    plt.show()

# Assuming load_fits_images is a function defined elsewhere to load FITS images
flat_images = load_fits_images(folder, "FLAT_R")
bias_images = load_fits_images(folder, "Bias")
science_images = load_fits_images(folder, "HAT-P-27")

output_folder = "D:\\TransitResearch\\2024-05-31\\calibrated_images2"
calibrate_and_save_images(science_images, flat_images, bias_images, output_folder)

# Clear the memory to avoid overflow
del flat_images
del bias_images
del science_images
# Out:
# C:\Users\Aiden\AppData\Local\Temp\ipykernel_9392\3469537190.py:8: DeprecationWarning: `photutils.Background2D` is a deprecated alias for `photutils.background.Background2D` and will be removed in the future. Instead, please use `from photutils.background import Background2D` to silence this warning.
#   from photutils import Background2D, MedianBackground
# C:\Users\Aiden\AppData\Local\Temp\ipykernel_9392\3469537190.py:8: DeprecationWarning: `photutils.MedianBackground` is a deprecated alias for `photutils.background.MedianBackground` and will be removed in the future. Instead, please use `from photutils.background import MedianBackground` to silence this warning.
#   from photutils import Background2D, MedianBackground
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_001_20240601_000821_376_PA116.06.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_002_20240601_000849_378_PA116.06.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_003_20240601_000916_828_PA116.06.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_004_20240601_000944_284_PA116.06.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_005_20240601_001012_037_PA116.06.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_006_20240601_001039_981_PA116.06.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_007_20240601_001108_065_PA116.06.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_008_20240601_001136_345_PA116.05.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_009_20240601_001204_007_PA116.05.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_010_20240601_001231_760_PA116.05.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_011_20240601_001259_582_PA116.05.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_012_20240601_001327_577_PA116.05.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_013_20240601_001355_340_PA116.05.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_014_20240601_001423_290_PA116.05.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_015_20240601_001451_292_PA116.05.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_016_20240601_001519_053_PA116.04.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_017_20240601_001546_790_PA116.04.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_018_20240601_001614_800_PA116.04.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_019_20240601_001642_341_PA116.04.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_020_20240601_001710_144_PA116.04.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_021_20240601_001737_918_PA116.04.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_022_20240601_001805_664_PA116.04.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_023_20240601_001833_744_PA116.03.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_024_20240601_001901_583_PA116.03.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_025_20240601_001929_288_PA116.03.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_026_20240601_001957_571_PA116.03.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_027_20240601_002025_354_PA116.03.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_028_20240601_002053_391_PA116.03.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_029_20240601_002121_235_PA116.03.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_030_20240601_002148_599_PA116.02.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_031_20240601_002215_968_PA116.02.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_032_20240601_002243_667_PA116.02.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_033_20240601_002311_568_PA116.02.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_034_20240601_002339_478_PA116.02.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_035_20240601_002406_906_PA116.02.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_036_20240601_002434_615_PA116.02.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_037_20240601_002502_375_PA116.02.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_038_20240601_002530_380_PA116.01.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_039_20240601_002558_305_PA116.01.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_040_20240601_002626_005_PA116.01.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_041_20240601_002654_060_PA116.01.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_042_20240601_002721_429_PA116.01.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_043_20240601_002749_674_PA116.01.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_044_20240601_002817_914_PA116.01.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_045_20240601_002845_688_PA116.01.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_046_20240601_002913_668_PA116.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_047_20240601_002940_983_PA116.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_048_20240601_003008_793_PA116.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_049_20240601_003036_393_PA116.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_050_20240601_003104_588_PA116.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_051_20240601_003132_088_PA116.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_052_20240601_003200_056_PA116.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_053_20240601_003227_869_PA116.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_054_20240601_003255_612_PA115.99.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_055_20240601_003323_102_PA115.99.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_056_20240601_003350_715_PA115.99.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_057_20240601_003418_550_PA115.99.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_058_20240601_003446_315_PA115.99.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_059_20240601_003513_859_PA115.99.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_060_20240601_003541_600_PA115.99.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_061_20240601_003609_741_PA115.98.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_062_20240601_003637_411_PA115.98.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_063_20240601_003705_650_PA115.98.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_064_20240601_003733_402_PA115.98.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_065_20240601_003801_206_PA115.98.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_066_20240601_003828_807_PA115.98.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_067_20240601_003856_547_PA115.98.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_068_20240601_003924_266_PA115.98.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_069_20240601_003951_712_PA115.98.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_070_20240601_004019_777_PA115.98.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_071_20240601_004047_318_PA115.97.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_072_20240601_004114_862_PA115.97.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_073_20240601_004142_389_PA115.97.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_074_20240601_004209_931_PA115.97.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_075_20240601_004237_419_PA115.97.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_076_20240601_004305_276_PA115.97.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_077_20240601_004333_203_PA115.97.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_078_20240601_004400_931_PA115.97.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_079_20240601_004428_481_PA115.96.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_080_20240601_004455_918_PA115.96.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_081_20240601_004523_768_PA115.96.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_082_20240601_004551_626_PA115.96.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_083_20240601_004619_691_PA115.96.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_084_20240601_004647_461_PA115.96.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_085_20240601_004715_545_PA115.96.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_086_20240601_004743_286_PA115.96.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_087_20240601_004811_010_PA115.95.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_088_20240601_004840_495_PA115.95.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_089_20240601_004909_677_PA115.95.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_090_20240601_004939_163_PA115.95.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_091_20240601_005008_453_PA115.95.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_092_20240601_005036_274_PA115.95.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_093_20240601_005104_387_PA115.95.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_094_20240601_005132_146_PA115.95.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_095_20240601_005200_152_PA115.95.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_096_20240601_005228_061_PA115.94.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_097_20240601_005255_790_PA115.94.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_098_20240601_005323_664_PA115.94.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_099_20240601_005351_720_PA115.94.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_100_20240601_005419_594_PA115.94.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_101_20240601_005447_181_PA115.94.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_102_20240601_005514_829_PA115.94.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_103_20240601_005542_482_PA115.94.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_104_20240601_005610_009_PA115.94.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_105_20240601_005637_714_PA115.94.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_106_20240601_005705_322_PA115.93.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_107_20240601_005733_025_PA115.93.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_108_20240601_005800_652_PA115.93.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_109_20240601_005828_364_PA115.93.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_110_20240601_005855_840_PA115.93.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_111_20240601_005923_272_PA115.93.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_112_20240601_005950_632_PA115.93.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_113_20240601_010018_656_PA115.93.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_114_20240601_010046_299_PA115.93.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_115_20240601_010113_989_PA115.93.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_116_20240601_010141_929_PA115.92.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_117_20240601_010209_583_PA115.92.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_118_20240601_010237_559_PA115.92.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_119_20240601_010304_884_PA115.92.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_120_20240601_010332_437_PA115.92.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_121_20240601_010359_812_PA115.92.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_122_20240601_010427_385_PA115.92.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_123_20240601_010454_767_PA115.92.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_124_20240601_010522_449_PA115.92.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_125_20240601_010550_348_PA115.92.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_126_20240601_010618_019_PA115.91.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_127_20240601_010645_918_PA115.91.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_128_20240601_010713_870_PA115.91.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_129_20240601_010741_184_PA115.91.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_130_20240601_010808_571_PA115.91.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_131_20240601_010836_617_PA115.91.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_132_20240601_010904_372_PA115.91.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_133_20240601_010932_317_PA115.91.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_134_20240601_011000_181_PA115.91.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_135_20240601_011027_603_PA115.91.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_136_20240601_011055_106_PA115.91.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_137_20240601_011122_530_PA115.9.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_138_20240601_011150_187_PA115.9.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_139_20240601_011217_544_PA115.9.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_140_20240601_011244_824_PA115.9.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_141_20240601_011312_396_PA115.9.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_142_20240601_011339_910_PA115.9.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_143_20240601_011407_258_PA115.9.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_144_20240601_011434_953_PA115.9.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_145_20240601_011502_497_PA115.9.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_146_20240601_011530_134_PA115.9.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_147_20240601_011557_421_PA115.9.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_148_20240601_011625_136_PA115.89.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_149_20240601_011652_584_PA115.89.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_150_20240601_011720_528_PA115.89.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_151_20240601_011748_253_PA115.89.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_152_20240601_011815_624_PA115.89.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_153_20240601_011843_620_PA115.89.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_154_20240601_011911_332_PA115.89.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_155_20240601_011939_212_PA115.89.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_156_20240601_012006_812_PA115.89.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_157_20240601_012034_755_PA115.89.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_158_20240601_012102_198_PA115.89.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_159_20240601_012129_878_PA115.89.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_160_20240601_012157_721_PA115.88.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_161_20240601_012225_807_PA115.88.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_162_20240601_012253_461_PA115.88.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_163_20240601_012320_773_PA115.88.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_164_20240601_012348_483_PA115.88.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_165_20240601_012415_800_PA115.88.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_166_20240601_012443_750_PA115.88.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_167_20240601_012511_541_PA115.88.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_168_20240601_012538_873_PA115.88.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_169_20240601_012606_460_PA115.88.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_170_20240601_012633_849_PA115.88.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_171_20240601_012701_827_PA115.88.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_172_20240601_012729_482_PA115.88.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_173_20240601_012757_132_PA115.87.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_174_20240601_012824_767_PA115.87.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_175_20240601_012852_397_PA115.87.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_176_20240601_012920_185_PA115.87.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_177_20240601_012950_326_PA115.87.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_178_20240601_013018_013_PA115.87.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_179_20240601_013045_692_PA115.87.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_180_20240601_013113_326_PA115.87.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_181_20240601_013140_710_PA115.87.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_182_20240601_013208_397_PA115.87.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_183_20240601_013236_478_PA115.87.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_184_20240601_013304_519_PA115.87.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_185_20240601_013332_054_PA115.87.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_186_20240601_013359_846_PA115.86.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_187_20240601_013427_149_PA115.86.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_188_20240601_013454_833_PA115.86.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_189_20240601_013522_937_PA115.86.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_190_20240601_013550_897_PA115.86.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_191_20240601_013618_554_PA115.86.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_192_20240601_013646_555_PA115.86.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_193_20240601_013841_029_PA115.86.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_194_20240601_013908_858_PA115.86.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_195_20240601_013936_800_PA115.86.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_196_20240601_014004_208_PA115.86.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_197_20240601_014032_400_PA115.86.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_198_20240601_014100_410_PA115.85.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_199_20240601_014128_307_PA115.85.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_200_20240601_014156_307_PA115.85.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_201_20240601_014224_598_PA115.85.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_202_20240601_014251_969_PA115.85.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_203_20240601_014320_018_PA115.85.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_204_20240601_014347_412_PA115.85.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_205_20240601_014414_994_PA115.85.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_206_20240601_014442_997_PA115.85.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_207_20240601_014511_092_PA115.85.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_208_20240601_014538_782_PA115.85.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_209_20240601_014607_112_PA115.85.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_210_20240601_014634_768_PA115.85.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_211_20240601_014702_382_PA115.85.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_212_20240601_014730_049_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_213_20240601_014758_386_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_214_20240601_014826_673_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_215_20240601_014854_314_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_216_20240601_014922_097_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_217_20240601_014949_835_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_218_20240601_015017_542_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_219_20240601_015045_016_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_220_20240601_015112_738_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_221_20240601_015140_374_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_222_20240601_015208_325_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_223_20240601_015235_945_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_224_20240601_015304_143_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_225_20240601_015331_938_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_226_20240601_015359_678_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_227_20240601_015427_734_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_228_20240601_015455_476_PA115.84.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_229_20240601_015523_235_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_230_20240601_015551_265_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_231_20240601_015619_220_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_232_20240601_015646_980_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_233_20240601_015714_667_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_234_20240601_015742_296_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_235_20240601_015809_909_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_236_20240601_015837_869_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_237_20240601_015905_619_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_238_20240601_015933_034_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_239_20240601_020001_094_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_240_20240601_020029_121_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_241_20240601_020057_161_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_242_20240601_020125_037_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_243_20240601_020152_685_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_244_20240601_020220_494_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_245_20240601_020248_589_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_246_20240601_020316_043_PA115.83.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_247_20240601_020344_415_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_248_20240601_020412_073_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_249_20240601_020439_863_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_250_20240601_020507_973_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_251_20240601_020535_568_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_252_20240601_020603_277_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_253_20240601_020630_992_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_254_20240601_020658_650_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_255_20240601_020726_561_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_256_20240601_020753_964_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_257_20240601_020821_636_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_258_20240601_020849_135_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_259_20240601_020917_088_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_260_20240601_020944_758_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_261_20240601_021012_554_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_262_20240601_021040_898_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_263_20240601_021108_267_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_264_20240601_021136_135_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_265_20240601_021203_875_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_266_20240601_021231_734_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_267_20240601_021259_874_PA115.82.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_268_20240601_021327_556_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_269_20240601_021355_269_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_270_20240601_021423_219_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_271_20240601_021450_635_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_272_20240601_021518_485_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_273_20240601_021546_235_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_274_20240601_021614_175_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_275_20240601_021641_634_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_276_20240601_021709_420_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_277_20240601_021736_902_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_278_20240601_021804_838_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_279_20240601_021832_794_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_280_20240601_021900_873_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_281_20240601_021928_351_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_282_20240601_021956_263_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_283_20240601_022024_534_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_284_20240601_022052_360_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_285_20240601_022120_271_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_286_20240601_022148_673_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_287_20240601_022216_731_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_288_20240601_022244_234_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_289_20240601_022311_812_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_290_20240601_022339_726_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_291_20240601_022407_661_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_292_20240601_022435_240_PA115.81.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_293_20240601_022503_210_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_294_20240601_022531_065_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_295_20240601_022558_829_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_296_20240601_022626_975_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_297_20240601_022654_896_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_298_20240601_022723_032_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_299_20240601_022751_135_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_300_20240601_022819_374_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_301_20240601_022847_057_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_302_20240601_022914_652_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_303_20240601_022942_875_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_304_20240601_023010_755_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_305_20240601_023038_625_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_306_20240601_023106_634_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_307_20240601_023134_231_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_308_20240601_023202_051_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_309_20240601_023230_128_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_310_20240601_023257_712_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_311_20240601_023325_380_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_312_20240601_023353_270_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_313_20240601_023420_910_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_314_20240601_023448_650_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_315_20240601_023516_881_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_316_20240601_023544_432_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_317_20240601_023615_312_PA115.8.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_318_20240601_023643_075_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_319_20240601_023710_669_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_320_20240601_023738_480_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_321_20240601_023806_340_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_322_20240601_023834_184_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_323_20240601_023901_743_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_324_20240601_023929_646_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_325_20240601_023957_677_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_326_20240601_024025_279_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_327_20240601_024052_809_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_328_20240601_024120_728_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_329_20240601_024148_387_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_330_20240601_024216_369_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_331_20240601_024243_916_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_332_20240601_024311_770_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_333_20240601_024339_798_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_334_20240601_024407_528_PA115.79.FIT
# Successfully calibrated and aligned HAT-P-27_LIGHT_R_19s_BIN2_-10C_335_20240601_024435_559_PA115.79.FIT

# %% [markdown]
# <h2 style="color: skyblue;" id="Aperture-Test">Section 4: Aperture Test</h2>
# <p>
# The aperture test is for choosing an acceptable aperture for your transit and reference stars. It involves increasing the aperture that you measure around the star so that it matches the stars size and doesn't include any extra background flux than needed, but still includes the entire star. The steps for aperture photometry are outlined below:
#
# Star detection- Either manually choose the pixels of the center of your transit and reference stars, or using a star detection library such as Photoutils.detection.DAOStarFinder, or photoutils.detection.find_peaks. If you are not manually choosing the stars then you can add certian checks to ensure you choose acceptable comp stars;
#
# ex:
# <li>check if the Gaussian FWHM is at least 2 pixels. This is a measure of the PSF. </li>
# <li>ensure the star is not too close to the edge; some stars will not be in frame for all images.</li>
# <li>choose the stars that are closest in brightness to your transit star.</li>
#
# once you have a list of stars you can run an aperture test for each. The aperture test involves increasing the aperture, and taking the sum of all the pixels each time. You then plot the sum for each aperture. If your images is focused properly and you have chosen an acceptable comp star, your curve should look something like the image below. As you can see from the plot, an aperture around 7 would capture the whole transit star in this case.
#
# ![image-2.png](attachment:image-2.png)
#
# you can also identify which stars are your comparison, and which is your transit star. first get a finder chart from <a href="http://var2.astro.cz/ETD/predictions.php">Exoplanet Transit Database</a> to help you find which star is yours. its not necessarily the brightest or in the exact center of your image, so you need this to identify your star.
#
# ![image-3.png](attachment:image-3.png)
# </p>

# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
from photutils.detection import find_peaks
from photutils.aperture import CircularAperture, aperture_photometry
from ipywidgets import IntSlider, Dropdown, Button, VBox, Output, interactive
from astropy.stats import sigma_clipped_stats
from photutils.background import Background2D, MedianBackground
from astropy.modeling.models import Gaussian2D
from astropy.modeling.fitting import LevMarLSQFitter

class ApertureTest:
    def __init__(self):
        self.selected_stars = []
        self.out = Output()

    def perform_test(self, filepath, aperture_sizes):
        try:
            with fits.open(filepath) as hdul:
                frame_data = hdul[0].data
        except Exception as e:
            print(f"Error opening FITS file: {e}")
            return

        bkg = Background2D(frame_data, (50, 50), filter_size=(3, 3), bkg_estimator=MedianBackground())
        data_sub = frame_data - bkg.background
        mean, median, std = sigma_clipped_stats(data_sub, sigma=3.0)
        threshold = 20.0 * std
        tbl = find_peaks(data_sub, threshold, box_size=11)

        if tbl is not None and len(tbl) > 0:
            sorted_sources = tbl[np.argsort(tbl['peak_value'])[::-1]][:40]
            positions = np.array(list(zip(sorted_sources['x_peak'], sorted_sources['y_peak'])))
            brightness = sorted_sources['peak_value']

            valid_positions = []
            valid_brightness = []

            for i, pos in enumerate(positions):
                x, y = pos
                size = 5
                if x-size < 0 or x+size >= data_sub.shape[1] or y-size < 0 or y+size >= data_sub.shape[0]:
                    continue

                cutout = data_sub[y-size:y+size+1, x-size:x+size+1]
                y_grid, x_grid = np.mgrid[:cutout.shape[0], :cutout.shape[1]]
                initial_guess = Gaussian2D(amplitude=cutout.max(), x_mean=size, y_mean=size)
                fit_p = LevMarLSQFitter()

                try:
                    gauss_fit = fit_p(initial_guess, x_grid, y_grid, cutout)
                    fwhm_x = 2.355 * gauss_fit.x_stddev.value
                    fwhm_y = 2.355 * gauss_fit.y_stddev.value
                    fwhm = np.sqrt(fwhm_x * fwhm_y)

                    if fwhm >= 2:
                        valid_positions.append(pos)
                        valid_brightness.append(brightness[i])
                except Exception as e:
                    print(f"Gaussian fit failed for star at position {pos}: {e}")

            if len(valid_positions) == 0:
                print("No valid stars found with FWHM >= 3 pixels.")
                return

            self.positions = np.array(valid_positions)
            self.brightness = np.array(valid_brightness)
            self.aperture_sums = []
            self.frame_data = frame_data
            self.aperture_sizes = aperture_sizes
            for aperture_size in aperture_sizes:
                aperture = CircularAperture(self.positions, r=aperture_size)
                phot_table = aperture_photometry(data_sub, aperture)
                aperture_sum_values = np.maximum(phot_table['aperture_sum'], 0)
                self.aperture_sums.append(aperture_sum_values)

            self.create_widgets()

    def create_widgets(self):
        star_selector = Dropdown(options=[(f'Star {i+1}', i+1) for i in range(len(self.positions))], description='Select Star:')
        star_type_selector = Dropdown(options=[('Transit Star', 'Transit Star'), ('Comparison Star', 'Comparison Star')], description='Star Type:')
        slider = IntSlider(min=self.aperture_sizes.min(), max=self.aperture_sizes.max(), step=1, value=self.aperture_sizes[len(self.aperture_sizes) // 2], description='Aperture Size:')
        add_button = Button(description='Add Star')

        def plot_pixel_count_and_image(selected_star, aperture_size):
            selected_star_idx = selected_star - 1
            fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 9))
            ax1.imshow(self.frame_data, cmap='gray', origin='lower')
            color = 'red'
            pos = self.positions[selected_star_idx]
            aperture = CircularAperture([pos], r=aperture_size)
            aperture.plot(ax1, color=color, label=f'Star {selected_star}')
            ax1.legend()
            ax1.set_title('Aperture Sizes')
            ax2.plot(self.aperture_sizes, [ap_sum[selected_star_idx] for ap_sum in self.aperture_sums], marker='o', color=color, label=f'Star {selected_star}')
            ax2.axvline(x=aperture_size, color=color, linestyle='--')
            ax2.set_xlabel('Aperture Size')
            ax2.set_ylabel('CCD Pixel Count')
            ax2.set_title('CCD Pixel Count vs Aperture Size')
            ax2.legend()
            plt.show()

        def add_star_to_list(selected_star, aperture_size, star_type):
            selected_star_idx = selected_star - 1
            pos = self.positions[selected_star_idx]
            self.selected_stars.append({'star': selected_star, 'position': pos, 'aperture_size': aperture_size, 'type': star_type})
            with self.out:
                print(f"Added {star_type} Star {selected_star} at position {pos} with aperture size {aperture_size}")
            plot_pixel_count_and_image(selected_star, aperture_size)

        def on_button_click(b):
            add_star_to_list(star_selector.value, slider.value, star_type_selector.value)

        add_button.on_click(on_button_click)

        display(VBox([star_type_selector, add_button, self.out]))
        
        interactive_plot = interactive(plot_pixel_count_and_image, selected_star=star_selector, aperture_size=slider)
        display(interactive_plot)

    def get_selected_stars(self):
        return self.selected_stars

# Perform the test on a single image file
aperture_test = ApertureTest()
aperture_sizes = np.arange(1, 20, 1)
aperture_test.perform_test("D:\\TransitResearch\\2024-05-31\\calibrated_images2\\HAT-P-27_LIGHT_R_19s_BIN2_-10C_001_20240601_000821_376_PA116.06.fit", aperture_sizes)
#aperture_test.perform_test("D:\\TransitResearch\\EXOTIC_sampledata-1.0.0\\EXOTIC_sampledata-1.0.0\\HatP32Dec202017\\HATP-32171220013343.fits", aperture_sizes)

# To access the selected stars list:
selected_stars = aperture_test.get_selected_stars()

# Example of accessing the pixel coordinates, aperture size, and star type
for star in selected_stars:
    print(f"Star: {star['star']}, Position: {star['position']}, Aperture Size: {star['aperture_size']}, Type: {star['type']}")
# Out:
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# 2024-06-17 13:32:31,667 - WARNING - The fit may be unsuccessful; check fit_info['message'] for more information.
# VBox(children=(Dropdown(description='Star Type:', options=(('Transit Star', 'Transit Star'), ('Comparison Star…
# interactive(children=(Dropdown(description='Select Star:', options=(('Star 1', 1), ('Star 2', 2), ('Star 3', 3…

# %% [markdown]
# <h2 style="color: skyblue;" id="Star-Tracking">Section 5: Star Tracking</h2>
# <p>
# While the 1 meter pointing accuracy is great, you still need to track your stars from image to image. A change in position of a single pixel can change the brightness inside the aperture too much to extract the roughly 1% change from your transit.
#
# This involves taking the list of chosen stars from your aperture test and correcting their position from image to image. This is done by recentering the aperture onto the brightest pixel or point.
# </p>

# %%
import os
from scipy.ndimage import center_of_mass
from astropy.io import fits

# Separate the stars into transit star and comparison stars
transit_star = [star for star in selected_stars if star['type'] == 'Transit Star'][0]
comparison_stars = [star for star in selected_stars if star['type'] == 'Comparison Star']

def calculate_centroid(image, position, box_size=15):
    y, x = position
    half_size = box_size // 2
    
    # Ensure sub-image does not go out of image bounds
    y_min = max(0, y - half_size)
    y_max = min(image.shape[0], y + half_size + 1)
    x_min = max(0, x - half_size)
    x_max = min(image.shape[1], x + half_size + 1)
    
    sub_image = image[y_min:y_max, x_min:x_max]
    
    # Calculate center of mass within the sub-image
    cy, cx = center_of_mass(sub_image)
    
    # Adjust centroid position to the main image's coordinate system
    return y_min + cy, x_min + cx

def recenter_stars(image_folder, keyword, initial_positions, box_size=15):
    recentered_positions = [initial_positions]
    
    for filename in sorted(os.listdir(image_folder)):
        if keyword in filename:
            file_path = os.path.join(image_folder, filename)
            with fits.open(file_path) as hdul:
                image = hdul[0].data

            current_positions = []
            for pos in initial_positions:
                centroid = calculate_centroid(image, pos, box_size)
                current_positions.append(centroid)
            recentered_positions.append(current_positions)
    
    return recentered_positions

# Example usage:
folder = "D:\\TransitResearch\\2024-05-31\\calibrated_images2"
#folder ="D:\\TransitResearch\\EXOTIC_sampledata-1.0.0\\EXOTIC_sampledata-1.0.0\\HatP32Dec202017"

keyword = "HAT"

# Get initial positions of the transit star and comparison stars
initial_positions = [transit_star['position']] + [star['position'] for star in comparison_stars]

# Box size can be customized based on the aperture size used
aperture_size = 50
recentered_positions = recenter_stars(folder, keyword, initial_positions, box_size=aperture_size)

# Print recentered positions for verification
for idx, positions in enumerate(recentered_positions):
    #print(f"Image {idx+1}:")
    for star_idx, pos in enumerate(positions):
        star_type = "Transit Star" if star_idx == 0 else f"Comparison Star {star_idx}"
        print(f"  {star_type}: Position {pos}")

# Proceed with differential photometry using the recentered_positions
# Out:
#   Transit Star: Position [749 454]
#   Comparison Star 1: Position [958 577]
#   Comparison Star 2: Position [597 298]
#   Transit Star: Position (749.0000167847511, 453.99989731500546)
#   Comparison Star 1: Position (957.9999049747802, 576.9997164902023)
#   Comparison Star 2: Position (596.9999656253985, 298.0001767763938)
#   Transit Star: Position (749.0000850601944, 454.0000065810664)
#   Comparison Star 1: Position (957.9996569901691, 576.9999920462094)
#   Comparison Star 2: Position (597.0000287657651, 298.00027592175326)
#   Transit Star: Position (748.9997724628369, 454.000137740519)
#   Comparison Star 1: Position (957.9995056578695, 577.0001636037051)
#   Comparison Star 2: Position (597.0004305962482, 297.999771560392)
#   Transit Star: Position (748.9997806989796, 454.00011349413694)
#   Comparison Star 1: Position (957.9996567995946, 576.9995903071754)
#   Comparison Star 2: Position (597.0000556355533, 297.99952084468583)
#   Transit Star: Position (749.0001289900683, 453.9998190281664)
#   Comparison Star 1: Position (957.9999216856982, 576.9995922934221)
#   Comparison Star 2: Position (596.9998604357139, 297.9999416604277)
#   Transit Star: Position (748.9999195229383, 454.00012841588574)
#   Comparison Star 1: Position (957.999386848577, 577.0000457229986)
#   Comparison Star 2: Position (597.0005210177858, 297.9999716124466)
#   Transit Star: Position (748.9999576472001, 453.999819078203)
#   Comparison Star 1: Position (957.999796881753, 576.9996104842081)
#   Comparison Star 2: Position (596.999857668297, 298.0000907316506)
#   Transit Star: Position (748.9999252915318, 453.9996944763062)
#   Comparison Star 1: Position (957.9999413617599, 577.0001963012307)
#   Comparison Star 2: Position (597.0002835743171, 297.99965888935407)
#   Transit Star: Position (748.9999609320857, 454.0000084336406)
#   Comparison Star 1: Position (957.9999948138842, 577.0001231548878)
#   Comparison Star 2: Position (597.0005187704846, 298.0000968512953)
#   Transit Star: Position (748.9996052090038, 453.99997550875526)
#   Comparison Star 1: Position (958.0001204008339, 577.0001098021518)
#   Comparison Star 2: Position (597.0002956466186, 297.9999355801222)
#   Transit Star: Position (748.99973887918, 453.99871704574207)
#   Comparison Star 1: Position (957.9994771918533, 577.0001389310704)
#   Comparison Star 2: Position (597.0001800903306, 297.999344693318)
#   Transit Star: Position (748.9996457436815, 453.9999048964626)
#   Comparison Star 1: Position (957.9999771343361, 576.9998514197298)
#   Comparison Star 2: Position (597.000114422903, 298.00008180887545)
#   Transit Star: Position (749.0000459341396, 453.9995216267219)
#   Comparison Star 1: Position (958.0000277444955, 577.0001741087589)
#   Comparison Star 2: Position (597.0002358764428, 297.9997348691655)
#   Transit Star: Position (748.9999763644888, 454.00022679737253)
#   Comparison Star 1: Position (957.9995367819243, 576.9997178016209)
#   Comparison Star 2: Position (597.0002115558984, 298.00017250647204)
#   Transit Star: Position (749.0002339937256, 454.0000758877815)
#   Comparison Star 1: Position (957.9997998562017, 576.9999755740616)
#   Comparison Star 2: Position (597.0001250256022, 297.9998062646618)
#   Transit Star: Position (749.000068818247, 454.00036592629203)
#   Comparison Star 1: Position (958.0001508932731, 577.000060848653)
#   Comparison Star 2: Position (597.0002496578547, 297.99968347250166)
#   Transit Star: Position (749.0001370005293, 453.9998653864765)
#   Comparison Star 1: Position (957.9996944155745, 577.0001066500834)
#   Comparison Star 2: Position (596.9998664453067, 298.0002083893914)
#   Transit Star: Position (749.0000531872969, 453.9999675386912)
#   Comparison Star 1: Position (957.9996946936105, 576.9998856880064)
#   Comparison Star 2: Position (597.0001073802025, 297.9999623582168)
#   Transit Star: Position (749.0001011283742, 454.0001905956818)
#   Comparison Star 1: Position (957.9997540304073, 577.0000619776199)
#   Comparison Star 2: Position (597.000154716777, 298.0000602795481)
#   Transit Star: Position (748.9997648371478, 453.99981359602333)
#   Comparison Star 1: Position (958.0001898705038, 577.0001404104307)
#   Comparison Star 2: Position (597.0000625428119, 297.99993536146155)
#   Transit Star: Position (748.9999900882723, 453.99987482273144)
#   Comparison Star 1: Position (957.9996451476318, 576.9998819226495)
#   Comparison Star 2: Position (596.9996752507789, 297.9997431833091)
#   Transit Star: Position (749.0002609332471, 453.9999092967675)
#   Comparison Star 1: Position (957.9997276131054, 576.9996365046388)
#   Comparison Star 2: Position (597.0000626703758, 297.99987546178846)
#   Transit Star: Position (748.9999284434607, 454.0000441673175)
#   Comparison Star 1: Position (957.9999820986876, 576.9997253561246)
#   Comparison Star 2: Position (597.0001784055027, 297.9997421537816)
#   Transit Star: Position (749.0000216304688, 454.000404942327)
#   Comparison Star 1: Position (957.9997748752817, 577.0001897528487)
#   Comparison Star 2: Position (596.9999684749396, 297.9999268945347)
#   Transit Star: Position (748.9998885577945, 454.00009748757776)
#   Comparison Star 1: Position (957.9999900436351, 577.0000096542756)
#   Comparison Star 2: Position (597.0001805135521, 298.0001082112087)
#   Transit Star: Position (748.9999570655037, 454.0001573631901)
#   Comparison Star 1: Position (957.9998903736191, 577.0000366354425)
#   Comparison Star 2: Position (596.9999547244938, 298.0001816506296)
#   Transit Star: Position (748.9998995680172, 454.00012727839436)
#   Comparison Star 1: Position (958.0001615246123, 577.0003242123496)
#   Comparison Star 2: Position (597.0000351446859, 297.99981792673475)
#   Transit Star: Position (749.0000943263902, 454.00006446962306)
#   Comparison Star 1: Position (957.9996666492216, 576.9999451414237)
#   Comparison Star 2: Position (597.0002146700622, 297.9998037997931)
#   Transit Star: Position (749.0001666117819, 454.0003754335977)
#   Comparison Star 1: Position (957.9996470379563, 576.9995988777728)
#   Comparison Star 2: Position (597.0003185436877, 298.0000840775933)
#   Transit Star: Position (748.999923452517, 454.00014359901803)
#   Comparison Star 1: Position (957.9997537866285, 577.000015464112)
#   Comparison Star 2: Position (597.000330852655, 298.0001355602162)
#   Transit Star: Position (748.9999456271823, 454.00035573410315)
#   Comparison Star 1: Position (957.9998020191671, 576.9996873960497)
#   Comparison Star 2: Position (596.9999438422527, 297.99996897431134)
#   Transit Star: Position (749.0001745634631, 454.0000940841523)
#   Comparison Star 1: Position (957.9997684468642, 577.0000749814208)
#   Comparison Star 2: Position (597.0003621893961, 298.000236711693)
#   Transit Star: Position (749.0005659932889, 453.99985667565545)
#   Comparison Star 1: Position (957.9999756392203, 576.9996869833973)
#   Comparison Star 2: Position (597.0001135308587, 297.99964317618753)
#   Transit Star: Position (748.9999293578988, 454.0000049186818)
#   Comparison Star 1: Position (957.9995333727586, 577.0000740564976)
#   Comparison Star 2: Position (597.0003655210395, 297.99980303316886)
#   Transit Star: Position (749.0001579454927, 454.0000844859235)
#   Comparison Star 1: Position (958.000071203315, 577.0001641926631)
#   Comparison Star 2: Position (597.0001919591886, 297.99998560762276)
#   Transit Star: Position (748.9999716853963, 453.99987704476047)
#   Comparison Star 1: Position (957.9998935207966, 576.9999032880098)
#   Comparison Star 2: Position (597.0000344794487, 297.9997689537476)
#   Transit Star: Position (749.0001701964089, 454.00019810081017)
#   Comparison Star 1: Position (957.9996082311139, 576.9996958291937)
#   Comparison Star 2: Position (597.000261952684, 298.00006318724644)
#   Transit Star: Position (749.0002272141517, 453.9996255181891)
#   Comparison Star 1: Position (957.999750545144, 577.000094933668)
#   Comparison Star 2: Position (597.0000934899067, 297.99969344759893)
#   Transit Star: Position (748.9999158066298, 454.00002172993413)
#   Comparison Star 1: Position (957.9997701150112, 576.9998245763337)
#   Comparison Star 2: Position (597.0000325070615, 297.99987788587674)
#   Transit Star: Position (748.9999990082238, 454.0001711552653)
#   Comparison Star 1: Position (957.9998115551795, 576.9995919133928)
#   Comparison Star 2: Position (597.0003955237659, 297.99965142539)
#   Transit Star: Position (749.0000919953633, 453.99988118144256)
#   Comparison Star 1: Position (957.9999231236502, 576.9995855438369)
#   Comparison Star 2: Position (597.0002170437473, 297.99988875758714)
#   Transit Star: Position (748.9998373762508, 453.9999087151446)
#   Comparison Star 1: Position (957.9996021433042, 576.9998093183444)
#   Comparison Star 2: Position (597.0000751104668, 297.99980047615503)
#   Transit Star: Position (749.0001634026154, 454.00031836931163)
#   Comparison Star 1: Position (957.9994901967145, 576.9996758774816)
#   Comparison Star 2: Position (597.0000378113918, 297.99998632837054)
#   Transit Star: Position (748.999840321079, 453.99995211356287)
#   Comparison Star 1: Position (957.9996217439451, 576.9998853939398)
#   Comparison Star 2: Position (597.000113579001, 298.0001630766913)
#   Transit Star: Position (749.0000767192488, 453.99996207066226)
#   Comparison Star 1: Position (957.9999537484484, 576.9999847233104)
#   Comparison Star 2: Position (596.9999074175311, 297.99973801600646)
#   Transit Star: Position (748.999523487702, 454.00010934079336)
#   Comparison Star 1: Position (957.9998049297179, 576.9999056792889)
#   Comparison Star 2: Position (596.9999655400302, 298.00015374811176)
#   Transit Star: Position (748.9999921978407, 453.9999917111585)
#   Comparison Star 1: Position (957.9996965467335, 576.999865075927)
#   Comparison Star 2: Position (596.9999583848264, 297.99965006788)
#   Transit Star: Position (749.0000048318865, 453.99992432331106)
#   Comparison Star 1: Position (957.9997970373189, 576.9995014544329)
#   Comparison Star 2: Position (597.0001244089248, 297.9999110864373)
#   Transit Star: Position (749.000070958268, 454.0000898374134)
#   Comparison Star 1: Position (957.9997734614475, 576.9998751725934)
#   Comparison Star 2: Position (596.9998657202128, 298.0000971536645)
#   Transit Star: Position (748.9999740668347, 453.99994713906966)
#   Comparison Star 1: Position (957.9999737515036, 576.9999384668249)
#   Comparison Star 2: Position (596.9999851391253, 298.000268253003)
#   Transit Star: Position (749.00009227585, 453.9997108573369)
#   Comparison Star 1: Position (957.9996493113706, 576.9997501393784)
#   Comparison Star 2: Position (596.9998234729467, 298.00018725269786)
#   Transit Star: Position (748.9999711753325, 453.99989446388986)
#   Comparison Star 1: Position (957.9996541105711, 576.9998054306709)
#   Comparison Star 2: Position (596.9999949167374, 298.00003638892275)
#   Transit Star: Position (748.9999683467926, 454.00012676399007)
#   Comparison Star 1: Position (957.9999309271989, 576.9996299331896)
#   Comparison Star 2: Position (597.0001101901663, 297.99997816417897)
#   Transit Star: Position (749.0002726680365, 453.99991624234605)
#   Comparison Star 1: Position (958.0002118472696, 576.9996839671945)
#   Comparison Star 2: Position (596.9998082447869, 297.9998105076127)
#   Transit Star: Position (749.0000542516724, 454.00021915446865)
#   Comparison Star 1: Position (957.9998831185559, 576.9999844177645)
#   Comparison Star 2: Position (597.0000999515455, 297.99990945241643)
#   Transit Star: Position (748.9997194279917, 454.0002080708214)
#   Comparison Star 1: Position (957.9997764175091, 576.9997805590519)
#   Comparison Star 2: Position (597.0000165834656, 297.99991128504774)
#   Transit Star: Position (748.9999859016813, 453.9997420783154)
#   Comparison Star 1: Position (957.999753838452, 576.9997829469484)
#   Comparison Star 2: Position (597.0000228307022, 297.99978882879566)
#   Transit Star: Position (748.999881591849, 454.00011759340765)
#   Comparison Star 1: Position (958.0001216336328, 576.9999200707542)
#   Comparison Star 2: Position (597.0003366133598, 297.9999200298706)
#   Transit Star: Position (749.0002399534774, 453.99998957434366)
#   Comparison Star 1: Position (957.999461057623, 576.9997517225013)
#   Comparison Star 2: Position (596.9998441507751, 298.00014221546274)
#   Transit Star: Position (749.0000312030435, 454.00004032860966)
#   Comparison Star 1: Position (957.9999828906698, 576.99967266733)
#   Comparison Star 2: Position (596.9999964064135, 298.0000604288935)
#   Transit Star: Position (749.0001946469863, 453.99996191308986)
#   Comparison Star 1: Position (957.9997493427027, 576.999708470812)
#   Comparison Star 2: Position (596.9999812957313, 298.0002404214636)
#   Transit Star: Position (748.9998160001568, 453.9998113600138)
#   Comparison Star 1: Position (957.9998240682816, 576.9996244381321)
#   Comparison Star 2: Position (597.0001143302297, 297.9999636995152)
#   Transit Star: Position (748.9997551953074, 454.0002583327027)
#   Comparison Star 1: Position (957.9998302991385, 576.9998384231027)
#   Comparison Star 2: Position (597.000168555513, 298.0001643188899)
#   Transit Star: Position (749.0001364195274, 454.0000053431701)
#   Comparison Star 1: Position (958.0001460076737, 577.0001567817931)
#   Comparison Star 2: Position (596.999787196456, 298.0000950287761)
#   Transit Star: Position (748.9999450684695, 454.0002039111511)
#   Comparison Star 1: Position (957.9998182486925, 577.0000868582254)
#   Comparison Star 2: Position (597.0003564549611, 297.9999069326764)
#   Transit Star: Position (748.9999544059878, 454.00026772941214)
#   Comparison Star 1: Position (957.9995063385854, 576.9998817362675)
#   Comparison Star 2: Position (597.0000531593919, 298.0000020049416)
#   Transit Star: Position (748.9996235531862, 454.0000546640256)
#   Comparison Star 1: Position (957.999868288019, 576.9999855028166)
#   Comparison Star 2: Position (597.0000523255358, 298.00009220364313)
#   Transit Star: Position (749.0001532291271, 454.0000446590347)
#   Comparison Star 1: Position (957.9998942628613, 576.9998154931474)
#   Comparison Star 2: Position (597.0000493049948, 298.0001130199297)
#   Transit Star: Position (749.0001153499812, 453.99989695488546)
#   Comparison Star 1: Position (957.9998273234431, 576.9999213838387)
#   Comparison Star 2: Position (596.9999306140326, 298.00010551034535)
#   Transit Star: Position (748.9999334479465, 454.0002207458993)
#   Comparison Star 1: Position (957.9996465112285, 576.9999713168705)
#   Comparison Star 2: Position (597.0000182128387, 298.00014385680055)
#   Transit Star: Position (749.000078109434, 454.0000992230732)
#   Comparison Star 1: Position (957.9995579357773, 576.9996376501904)
#   Comparison Star 2: Position (597.0001158269399, 298.0000448778339)
#   Transit Star: Position (749.0002645486866, 453.99985345888575)
#   Comparison Star 1: Position (958.0000852376864, 576.9999595635622)
#   Comparison Star 2: Position (597.0002894266944, 298.0002212157976)
#   Transit Star: Position (748.9998225189345, 453.99990371036637)
#   Comparison Star 1: Position (958.0002720109769, 576.9999048495581)
#   Comparison Star 2: Position (597.0000139841394, 297.9999744861529)
#   Transit Star: Position (749.0001587388574, 454.00000680168733)
#   Comparison Star 1: Position (957.9997118870609, 576.9999648602707)
#   Comparison Star 2: Position (596.999957885449, 297.99994792348923)
#   Transit Star: Position (748.9997664585321, 454.0000679054264)
#   Comparison Star 1: Position (957.9999175444594, 576.9996383599122)
#   Comparison Star 2: Position (597.0000091073005, 297.9997631966347)
#   Transit Star: Position (748.9998951656601, 453.99959966355686)
#   Comparison Star 1: Position (957.9994887573328, 576.9998560048663)
#   Comparison Star 2: Position (596.9999692121721, 298.00004643764595)
#   Transit Star: Position (749.000094437157, 454.00023690412263)
#   Comparison Star 1: Position (957.9999759759418, 576.9998905825224)
#   Comparison Star 2: Position (597.0000439168634, 297.99983570178193)
#   Transit Star: Position (749.0001399987395, 453.9998441204778)
#   Comparison Star 1: Position (958.0001112023549, 577.0002202070808)
#   Comparison Star 2: Position (596.9998373666524, 297.999837073586)
#   Transit Star: Position (748.9996972100598, 454.0000239711587)
#   Comparison Star 1: Position (957.9997131362318, 576.9997266990127)
#   Comparison Star 2: Position (597.0000645778962, 298.00004285198577)
#   Transit Star: Position (748.9998871588722, 454.000074969534)
#   Comparison Star 1: Position (957.9999233692015, 576.9997194165228)
#   Comparison Star 2: Position (597.0000508065006, 298.0002358671788)
#   Transit Star: Position (748.9998543036442, 453.9998420217319)
#   Comparison Star 1: Position (957.9999281577964, 576.9993439118008)
#   Comparison Star 2: Position (597.0002032921493, 298.00027681660623)
#   Transit Star: Position (748.9996812471951, 453.9999442562442)
#   Comparison Star 1: Position (957.9999462636627, 576.9995443091617)
#   Comparison Star 2: Position (597.0003485010643, 297.99984202180053)
#   Transit Star: Position (748.9998738115183, 454.00009212525026)
#   Comparison Star 1: Position (957.9995076033131, 576.9997304670406)
#   Comparison Star 2: Position (597.0000892682295, 298.00019703078283)
#   Transit Star: Position (749.0001761558989, 454.00013170609395)
#   Comparison Star 1: Position (957.9996162550796, 576.9999111900454)
#   Comparison Star 2: Position (596.9998687237086, 297.9997915887303)
#   Transit Star: Position (749.00014248048, 454.0000630249126)
#   Comparison Star 1: Position (957.9995196425309, 577.0000846909049)
#   Comparison Star 2: Position (597.0000382354598, 298.00023361350895)
#   Transit Star: Position (749.0002412022312, 454.0000059203029)
#   Comparison Star 1: Position (957.9996517038328, 576.9997189989061)
#   Comparison Star 2: Position (596.9998978632096, 298.0000737964097)
#   Transit Star: Position (748.9999336555478, 453.999806507275)
#   Comparison Star 1: Position (957.9993395469387, 576.9999670397646)
#   Comparison Star 2: Position (597.0001440756856, 297.9998615702616)
#   Transit Star: Position (748.9999896638142, 453.99998202317823)
#   Comparison Star 1: Position (957.9999342389679, 576.9995314170241)
#   Comparison Star 2: Position (596.9999910596982, 297.9999143582943)
#   Transit Star: Position (749.0000724453351, 453.9999864895842)
#   Comparison Star 1: Position (957.999667901676, 576.9999297798395)
#   Comparison Star 2: Position (596.9998301664133, 297.99984407409295)
#   Transit Star: Position (748.9999139006537, 454.0000543093247)
#   Comparison Star 1: Position (957.9996264615046, 576.9999146866148)
#   Comparison Star 2: Position (597.0002584942429, 297.99992552317457)
#   Transit Star: Position (748.999871071729, 453.99996302164374)
#   Comparison Star 1: Position (957.9997695189355, 576.9996863148561)
#   Comparison Star 2: Position (597.0000810855124, 298.0001396832173)
#   Transit Star: Position (748.999876470551, 453.9996668929309)
#   Comparison Star 1: Position (957.9998604353461, 577.0000358200284)
#   Comparison Star 2: Position (597.0002221163705, 297.99989166894557)
#   Transit Star: Position (748.999797330061, 454.0003067526028)
#   Comparison Star 1: Position (957.9998591558935, 576.999856309547)
#   Comparison Star 2: Position (597.000038272217, 297.9999682146723)
#   Transit Star: Position (749.0000484035999, 453.9999008482943)
#   Comparison Star 1: Position (957.9999821118331, 576.9998309429687)
#   Comparison Star 2: Position (597.0001821083288, 298.00020935007217)
#   Transit Star: Position (749.0002173100572, 454.000504835092)
#   Comparison Star 1: Position (957.9999474783109, 576.9995897445399)
#   Comparison Star 2: Position (596.9997582293781, 297.9998301069396)
#   Transit Star: Position (749.0001209305516, 454.0002615665098)
#   Comparison Star 1: Position (957.9998967177258, 576.9997325991018)
#   Comparison Star 2: Position (597.0000176505173, 297.99987097196254)
#   Transit Star: Position (749.000051796759, 454.0001069508504)
#   Comparison Star 1: Position (957.9996463318479, 576.9996312545188)
#   Comparison Star 2: Position (596.9998671626043, 297.9997140222113)
#   Transit Star: Position (749.0000585372084, 453.9999851551018)
#   Comparison Star 1: Position (957.9997079621961, 577.0000143195592)
#   Comparison Star 2: Position (597.000525360894, 297.9997592701879)
#   Transit Star: Position (748.9999420588872, 453.99979683570064)
#   Comparison Star 1: Position (957.9995899674408, 576.9999534209605)
#   Comparison Star 2: Position (597.0001072661307, 297.9997884793178)
#   Transit Star: Position (749.0000904974048, 454.00025820133817)
#   Comparison Star 1: Position (958.0000080056768, 577.0000178149962)
#   Comparison Star 2: Position (597.0000060058253, 297.99983450837544)
#   Transit Star: Position (748.9999957643215, 454.0002907074695)
#   Comparison Star 1: Position (957.9998736068476, 576.9999657214496)
#   Comparison Star 2: Position (596.9996034881985, 297.99994580022)
#   Transit Star: Position (748.9999936910075, 453.9996474159103)
#   Comparison Star 1: Position (957.9994389856206, 576.9996028040588)
#   Comparison Star 2: Position (597.0001025532629, 298.0001127337733)
#   Transit Star: Position (749.000161475974, 454.00005383145884)
#   Comparison Star 1: Position (958.0001978958252, 576.9999201970554)
#   Comparison Star 2: Position (597.0000553279374, 297.9998427972489)
#   Transit Star: Position (749.0000383349557, 454.0001066678797)
#   Comparison Star 1: Position (957.9999211032612, 576.9996890125379)
#   Comparison Star 2: Position (597.0002018884294, 298.00043945635866)
#   Transit Star: Position (749.0001502783829, 454.0000609945964)
#   Comparison Star 1: Position (957.9998433653587, 577.0001178066525)
#   Comparison Star 2: Position (597.0004757549657, 298.00034931502046)
#   Transit Star: Position (749.0000415497585, 454.00018044837776)
#   Comparison Star 1: Position (957.9999067249508, 576.9997755013112)
#   Comparison Star 2: Position (597.0001648634614, 297.99999450485745)
#   Transit Star: Position (748.9997216583638, 453.99984675811834)
#   Comparison Star 1: Position (957.999826388504, 577.0000591108768)
#   Comparison Star 2: Position (597.0003511533245, 298.0000025383765)
#   Transit Star: Position (749.0000638891992, 453.999949123935)
#   Comparison Star 1: Position (957.9997106072632, 577.0000043692662)
#   Comparison Star 2: Position (596.9999081974676, 297.9996821094155)
#   Transit Star: Position (748.9998470793927, 454.00002185408397)
#   Comparison Star 1: Position (957.9999151743225, 576.9996143865272)
#   Comparison Star 2: Position (597.0001488064812, 297.9999428864111)
#   Transit Star: Position (748.9998369092249, 454.00011040313933)
#   Comparison Star 1: Position (957.9998627254352, 576.9995421810017)
#   Comparison Star 2: Position (597.0000454597124, 297.99985984724816)
#   Transit Star: Position (748.999841148841, 454.00020620128834)
#   Comparison Star 1: Position (957.9998784129907, 576.999961981487)
#   Comparison Star 2: Position (597.0003001090902, 298.0000475234925)
#   Transit Star: Position (748.999799229462, 454.00007156938875)
#   Comparison Star 1: Position (957.999740179735, 576.9999747063255)
#   Comparison Star 2: Position (597.0000209253508, 298.00004371986176)
#   Transit Star: Position (749.0000992342432, 454.0003424786274)
#   Comparison Star 1: Position (957.9996014331143, 577.000154461456)
#   Comparison Star 2: Position (597.0001712568196, 298.0004370704351)
#   Transit Star: Position (749.0000017234917, 453.99989652025306)
#   Comparison Star 1: Position (957.9998482857947, 576.9997254198614)
#   Comparison Star 2: Position (597.000270611912, 298.00015715043554)
#   Transit Star: Position (749.0001501278693, 454.00001456791983)
#   Comparison Star 1: Position (958.0003198555664, 577.0002157910452)
#   Comparison Star 2: Position (597.0001870425763, 298.00013169940274)
#   Transit Star: Position (749.0000791260734, 453.999955671135)
#   Comparison Star 1: Position (957.9999111842587, 576.9996695470844)
#   Comparison Star 2: Position (597.000297591349, 298.00010886241716)
#   Transit Star: Position (748.9997706180391, 454.0000997267349)
#   Comparison Star 1: Position (957.9998909702304, 576.9999229871677)
#   Comparison Star 2: Position (597.0002101570753, 298.0000062541798)
#   Transit Star: Position (749.000079959929, 454.00035544557295)
#   Comparison Star 1: Position (958.0000812941248, 576.9997996424913)
#   Comparison Star 2: Position (597.0000823606962, 297.99996513310725)
#   Transit Star: Position (748.9996862933841, 454.0000695760088)
#   Comparison Star 1: Position (957.9997864615069, 576.9999161590887)
#   Comparison Star 2: Position (597.0001714619851, 297.9999588778934)
#   Transit Star: Position (749.0002130659674, 454.000458427947)
#   Comparison Star 1: Position (957.9997797745464, 576.9998139198667)
#   Comparison Star 2: Position (596.9998724485109, 298.00001463574813)
#   Transit Star: Position (748.9998727415327, 454.00014043504916)
#   Comparison Star 1: Position (957.9998449070322, 576.9996377336548)
#   Comparison Star 2: Position (596.9999456522326, 297.9998959123585)
#   Transit Star: Position (748.9999372837025, 454.0001438058783)
#   Comparison Star 1: Position (957.9998470340411, 576.9996693001343)
#   Comparison Star 2: Position (596.9999902206125, 298.000007900442)
#   Transit Star: Position (748.9999341911772, 454.0001832433621)
#   Comparison Star 1: Position (957.9997018656868, 576.9994689497647)
#   Comparison Star 2: Position (596.9997726858768, 298.0000480287135)
#   Transit Star: Position (749.0000946661969, 453.99978961505565)
#   Comparison Star 1: Position (958.0000900535846, 576.9997316757245)
#   Comparison Star 2: Position (597.0001100405399, 297.9997032994314)
#   Transit Star: Position (749.0000249323572, 454.00030643087086)
#   Comparison Star 1: Position (957.9999417497928, 576.9997301128356)
#   Comparison Star 2: Position (597.0000993764542, 297.9999327299436)
#   Transit Star: Position (748.9998306281509, 454.0002960716879)
#   Comparison Star 1: Position (957.9996507212184, 576.9998981464064)
#   Comparison Star 2: Position (596.9998797973852, 298.00006681182697)
#   Transit Star: Position (749.00000397979, 454.0000953109351)
#   Comparison Star 1: Position (958.0000658310821, 576.9999380524235)
#   Comparison Star 2: Position (597.0003581541345, 298.0000777008587)
#   Transit Star: Position (748.9999455636695, 454.0000176143989)
#   Comparison Star 1: Position (957.9995842083551, 576.9998832523786)
#   Comparison Star 2: Position (597.0001880791268, 297.9998716751205)
#   Transit Star: Position (748.999685155732, 453.99975055739156)
#   Comparison Star 1: Position (957.9995658764391, 576.9997886636554)
#   Comparison Star 2: Position (597.00019439483, 297.9998599436342)
#   Transit Star: Position (748.9999379154468, 453.9999838552876)
#   Comparison Star 1: Position (957.9996427042638, 576.9996213610024)
#   Comparison Star 2: Position (596.9997844681874, 297.9997835209308)
#   Transit Star: Position (749.0001154745529, 454.00029631738846)
#   Comparison Star 1: Position (957.9999565066731, 576.9998773524699)
#   Comparison Star 2: Position (597.0003624074179, 297.99997499866714)
#   Transit Star: Position (748.9996282209215, 453.9998650602411)
#   Comparison Star 1: Position (957.9995741111992, 577.0001748078773)
#   Comparison Star 2: Position (597.0001157310863, 297.99982313851604)
#   Transit Star: Position (748.9997736523288, 453.9997032997215)
#   Comparison Star 1: Position (957.9994883581561, 576.9999684741866)
#   Comparison Star 2: Position (597.0000828909374, 298.0000221891902)
#   Transit Star: Position (749.0001948000423, 454.0000252777689)
#   Comparison Star 1: Position (957.9995649042294, 576.9999082990554)
#   Comparison Star 2: Position (597.000163335126, 298.00002779490933)
#   Transit Star: Position (748.9997374951114, 453.9997861682024)
#   Comparison Star 1: Position (957.9998548241114, 576.9999592295408)
#   Comparison Star 2: Position (597.0004671020407, 297.9996681131114)
#   Transit Star: Position (748.9998290771923, 454.0001698449023)
#   Comparison Star 1: Position (957.9995273513855, 576.999729300246)
#   Comparison Star 2: Position (596.9998173314676, 297.99976294137036)
#   Transit Star: Position (748.9999996680638, 454.00005122053983)
#   Comparison Star 1: Position (957.9997776827017, 576.9997898101367)
#   Comparison Star 2: Position (597.0000755496409, 297.9997580467982)
#   Transit Star: Position (749.0002660883113, 454.0002141406112)
#   Comparison Star 1: Position (957.9998433619276, 576.9997175091011)
#   Comparison Star 2: Position (597.0000104461097, 297.99981358564577)
#   Transit Star: Position (748.9996784478737, 453.9999477820579)
#   Comparison Star 1: Position (958.000024078199, 576.9998310594491)
#   Comparison Star 2: Position (597.000163735074, 297.9998440399555)
#   Transit Star: Position (749.0000078458412, 454.000178320233)
#   Comparison Star 1: Position (957.9996699395149, 576.999752303095)
#   Comparison Star 2: Position (597.0000132534275, 298.0000152063514)
#   Transit Star: Position (748.9999201055182, 454.00024550148976)
#   Comparison Star 1: Position (957.9997957933443, 576.9996078563133)
#   Comparison Star 2: Position (597.000051016728, 297.9998440574762)
#   Transit Star: Position (748.9999833700339, 453.9999515246859)
#   Comparison Star 1: Position (957.9997759053264, 577.0000249407082)
#   Comparison Star 2: Position (596.9999742672214, 297.9999938194275)
#   Transit Star: Position (748.9996291271169, 454.00001858215614)
#   Comparison Star 1: Position (957.9999919933309, 576.9993927414207)
#   Comparison Star 2: Position (597.0002698287892, 297.9999724921483)
#   Transit Star: Position (748.9997182054665, 454.0002034940273)
#   Comparison Star 1: Position (958.0001118852392, 576.9999956951204)
#   Comparison Star 2: Position (596.9999180193295, 298.0001795586949)
#   Transit Star: Position (749.000153421909, 453.9998032853771)
#   Comparison Star 1: Position (957.9997689287691, 576.9995761957409)
#   Comparison Star 2: Position (596.9997092994768, 297.99994208400176)
#   Transit Star: Position (749.0001547601212, 454.00037055809656)
#   Comparison Star 1: Position (957.999871559145, 576.9996768323355)
#   Comparison Star 2: Position (597.0002791068845, 297.9997493714726)
#   Transit Star: Position (748.9998510081564, 454.000132337186)
#   Comparison Star 1: Position (958.0000415560363, 576.9999754567954)
#   Comparison Star 2: Position (597.0000946135999, 298.00018966314764)
#   Transit Star: Position (748.9999450326546, 454.0001072274649)
#   Comparison Star 1: Position (957.9997383122659, 576.9998291043548)
#   Comparison Star 2: Position (597.0001135597747, 297.99993233941075)
#   Transit Star: Position (749.0004841955747, 454.0001644058735)
#   Comparison Star 1: Position (957.9999062006308, 576.999805440384)
#   Comparison Star 2: Position (597.0002138401645, 297.99989164521344)
#   Transit Star: Position (748.9997759139233, 454.0000037986432)
#   Comparison Star 1: Position (957.9996932783637, 576.9998377640762)
#   Comparison Star 2: Position (596.9998043171088, 298.0001306619735)
#   Transit Star: Position (749.0001050179349, 454.00017531168135)
#   Comparison Star 1: Position (957.9997542526395, 577.0001662018691)
#   Comparison Star 2: Position (597.000136217613, 297.9999385969438)
#   Transit Star: Position (748.9995787212772, 454.00039200315933)
#   Comparison Star 1: Position (957.9998088988177, 576.9998133017441)
#   Comparison Star 2: Position (597.0001212818138, 297.9997792516402)
#   Transit Star: Position (748.9998642008995, 453.9998072557386)
#   Comparison Star 1: Position (957.999725317496, 576.9998174361384)
#   Comparison Star 2: Position (597.0005106462031, 298.0001362041338)
#   Transit Star: Position (748.9998650563065, 454.0000797900171)
#   Comparison Star 1: Position (957.9997793288439, 576.9997439096207)
#   Comparison Star 2: Position (597.0002353492497, 297.999952406978)
#   Transit Star: Position (748.9999161587258, 453.99986508751107)
#   Comparison Star 1: Position (957.9997302174387, 576.9996834488616)
#   Comparison Star 2: Position (597.0000616848043, 297.99982592752707)
#   Transit Star: Position (748.9998792784219, 454.00009547142037)
#   Comparison Star 1: Position (957.9994693728559, 576.9996526429237)
#   Comparison Star 2: Position (597.0000647526923, 297.9995342287378)
#   Transit Star: Position (748.9999344569565, 453.9998758256467)
#   Comparison Star 1: Position (957.9995769541814, 577.0000534655495)
#   Comparison Star 2: Position (597.000049262779, 297.9997926727581)
#   Transit Star: Position (749.0002456177461, 454.0001060727367)
#   Comparison Star 1: Position (957.9997132035451, 577.0000050811254)
#   Comparison Star 2: Position (597.0003027415379, 298.0000269439692)
#   Transit Star: Position (749.000024753944, 454.0002625487229)
#   Comparison Star 1: Position (957.9996454141982, 576.9997628841885)
#   Comparison Star 2: Position (597.0001532045097, 297.9997098104573)
#   Transit Star: Position (748.9999956310656, 454.00021647557537)
#   Comparison Star 1: Position (957.9997722218934, 577.0001566544563)
#   Comparison Star 2: Position (597.0001722968836, 297.999893592029)
#   Transit Star: Position (748.999922904899, 453.999987222338)
#   Comparison Star 1: Position (957.999541245069, 577.0000160213909)
#   Comparison Star 2: Position (597.0001867731888, 297.99997950269244)
#   Transit Star: Position (748.999819923708, 454.0001264526299)
#   Comparison Star 1: Position (957.9997593475075, 576.9998615210575)
#   Comparison Star 2: Position (597.0004349008414, 297.9997717773726)
#   Transit Star: Position (749.0000685383119, 454.0001533645662)
#   Comparison Star 1: Position (957.9999565986782, 576.9999898008011)
#   Comparison Star 2: Position (597.0002768990972, 297.9998655363274)
#   Transit Star: Position (749.0000164932686, 453.99998346837094)
#   Comparison Star 1: Position (958.0000502844171, 576.9998099548029)
#   Comparison Star 2: Position (596.9999025829309, 297.9997131884069)
#   Transit Star: Position (749.0000347893368, 453.9998789244898)
#   Comparison Star 1: Position (957.9997788029684, 576.9999892288618)
#   Comparison Star 2: Position (597.0001203038116, 297.9996200817751)
#   Transit Star: Position (748.999626550127, 453.9999323556905)
#   Comparison Star 1: Position (958.0001383524582, 576.999902358481)
#   Comparison Star 2: Position (597.0003805682984, 297.99964193283404)
#   Transit Star: Position (748.9999375843263, 454.0001614717917)
#   Comparison Star 1: Position (957.9998302624454, 576.9996355462256)
#   Comparison Star 2: Position (597.0000584509046, 298.0001439624092)
#   Transit Star: Position (749.000172647061, 453.9999772612769)
#   Comparison Star 1: Position (957.9995326088458, 576.999798565422)
#   Comparison Star 2: Position (597.000263028646, 297.9997083633621)
#   Transit Star: Position (748.9999683423124, 454.0003189943863)
#   Comparison Star 1: Position (957.9996338101654, 576.9996995339972)
#   Comparison Star 2: Position (596.9997635440723, 297.9998899995653)
#   Transit Star: Position (748.9997975518492, 453.9999380954062)
#   Comparison Star 1: Position (957.9996813567907, 576.9995571176786)
#   Comparison Star 2: Position (597.0000131920054, 298.0000453323223)
#   Transit Star: Position (749.000127327048, 453.9999034411247)
#   Comparison Star 1: Position (957.9999805059537, 576.9999552501787)
#   Comparison Star 2: Position (597.0001116843802, 298.00018694888445)
#   Transit Star: Position (749.0001484468773, 453.99987609297614)
#   Comparison Star 1: Position (957.9996820986519, 577.0000077742188)
#   Comparison Star 2: Position (597.0003913127235, 297.9997216063433)
#   Transit Star: Position (749.0000986549917, 453.9999101165588)
#   Comparison Star 1: Position (957.9996190368986, 576.9998152474551)
#   Comparison Star 2: Position (597.000410405392, 297.9997436303287)
#   Transit Star: Position (749.0001845568768, 454.00008746308345)
#   Comparison Star 1: Position (957.999500047495, 576.9996604865094)
#   Comparison Star 2: Position (596.9997796309963, 298.00002259844075)
#   Transit Star: Position (749.0002502575977, 454.00020444302163)
#   Comparison Star 1: Position (957.9995076213504, 577.000238734797)
#   Comparison Star 2: Position (597.0000662648355, 297.99964265773167)
#   Transit Star: Position (748.9998734958546, 453.9993668715288)
#   Comparison Star 1: Position (957.9996145400461, 576.9999032464351)
#   Comparison Star 2: Position (597.0001629758095, 298.00001369723327)
#   Transit Star: Position (748.9996634781594, 454.0001790343679)
#   Comparison Star 1: Position (957.9996312930642, 576.9997956338849)
#   Comparison Star 2: Position (596.9997336611549, 297.9997891913684)
#   Transit Star: Position (749.0001421421161, 453.9997548922332)
#   Comparison Star 1: Position (957.9997643416345, 576.9997831673055)
#   Comparison Star 2: Position (596.9999108506869, 297.9997601957214)
#   Transit Star: Position (748.9998048560251, 453.99955902824456)
#   Comparison Star 1: Position (957.9993439703529, 576.9998973643493)
#   Comparison Star 2: Position (597.00004971899, 298.0001395438053)
#   Transit Star: Position (748.9998599325595, 454.0000931118762)
#   Comparison Star 1: Position (957.9999287863104, 576.9999259452322)
#   Comparison Star 2: Position (596.9998517436953, 298.0001137068373)
#   Transit Star: Position (748.9999447077497, 453.99988539504744)
#   Comparison Star 1: Position (957.9998940977722, 576.9999441838808)
#   Comparison Star 2: Position (597.0002156033822, 298.0001870857267)
#   Transit Star: Position (749.0001460064898, 454.0001770811973)
#   Comparison Star 1: Position (957.9995770558565, 576.9997894363701)
#   Comparison Star 2: Position (597.0002156321174, 297.99984177358476)
#   Transit Star: Position (748.9999043804968, 453.9999608286987)
#   Comparison Star 1: Position (957.9996783440123, 577.0003568400634)
#   Comparison Star 2: Position (597.0001648262181, 297.99969232733736)
#   Transit Star: Position (748.9998784942937, 454.00021524634207)
#   Comparison Star 1: Position (957.9998217212042, 576.9998471053192)
#   Comparison Star 2: Position (597.0002607746221, 298.0001838283497)
#   Transit Star: Position (749.0000624569827, 454.000066457668)
#   Comparison Star 1: Position (957.9996036181752, 576.9996090191921)
#   Comparison Star 2: Position (597.0003260161092, 298.0000074042892)
#   Transit Star: Position (749.0002870424772, 453.99995942612003)
#   Comparison Star 1: Position (957.9997335068329, 576.999915640706)
#   Comparison Star 2: Position (597.0002136302497, 297.9998415716531)
#   Transit Star: Position (749.0002045798946, 453.9998925409313)
#   Comparison Star 1: Position (957.9996579391338, 576.9998592121156)
#   Comparison Star 2: Position (597.0003793223347, 298.00008070422473)
#   Transit Star: Position (749.0004638176746, 453.99973936255554)
#   Comparison Star 1: Position (957.9996242604236, 577.0001049054749)
#   Comparison Star 2: Position (597.000299171135, 298.0001231779178)
#   Transit Star: Position (749.0005193435828, 453.9997060512348)
#   Comparison Star 1: Position (957.9995972837269, 577.0000214577257)
#   Comparison Star 2: Position (596.9998157956438, 297.9996798910613)
#   Transit Star: Position (749.0001457505052, 453.99987840456487)
#   Comparison Star 1: Position (957.999382463055, 576.9996960497446)
#   Comparison Star 2: Position (597.0000009592114, 297.9999493338618)
#   Transit Star: Position (748.9998050861435, 453.99949415324465)
#   Comparison Star 1: Position (957.9998919800086, 577.0002229295122)
#   Comparison Star 2: Position (597.0002190850076, 297.9999540356281)
#   Transit Star: Position (749.0002722646022, 453.99987017731627)
#   Comparison Star 1: Position (957.9996764051275, 576.9997715996832)
#   Comparison Star 2: Position (597.0003804391015, 297.9998806742796)
#   Transit Star: Position (749.0004742390714, 454.0000118975894)
#   Comparison Star 1: Position (957.9993081213952, 576.9997989408286)
#   Comparison Star 2: Position (596.9997826246017, 297.99989281917567)
#   Transit Star: Position (749.000797432936, 453.99973719364067)
#   Comparison Star 1: Position (958.0000033373291, 576.9995284925003)
#   Comparison Star 2: Position (596.9998024081981, 298.0000406236972)
#   Transit Star: Position (749.0004308628692, 453.999725178271)
#   Comparison Star 1: Position (958.0001014266883, 576.9998624660003)
#   Comparison Star 2: Position (597.0002097070294, 297.9996478770761)
#   Transit Star: Position (749.0002611651568, 453.99937572584264)
#   Comparison Star 1: Position (958.0001335490973, 576.9998635395109)
#   Comparison Star 2: Position (596.9998573265434, 297.999519728311)
#   Transit Star: Position (749.0001795478696, 453.99975244516435)
#   Comparison Star 1: Position (957.9996426538814, 576.9998818155087)
#   Comparison Star 2: Position (597.0003004057562, 297.99975831066706)
#   Transit Star: Position (749.0002917942879, 453.99988821206074)
#   Comparison Star 1: Position (957.9998042978731, 577.000037677449)
#   Comparison Star 2: Position (597.0002396683781, 297.999926514176)
#   Transit Star: Position (749.000141571442, 453.99986048586396)
#   Comparison Star 1: Position (957.9997532735352, 576.9997326920856)
#   Comparison Star 2: Position (597.0000697710656, 297.99978544315337)
#   Transit Star: Position (749.0000402157051, 453.99978018431676)
#   Comparison Star 1: Position (958.0001944259087, 576.9999343604584)
#   Comparison Star 2: Position (597.0003189605914, 297.9996544133082)
#   Transit Star: Position (749.0001892435203, 453.99943301215194)
#   Comparison Star 1: Position (957.9995149282421, 576.999935449099)
#   Comparison Star 2: Position (597.0000467194435, 297.99976008221813)
#   Transit Star: Position (749.0002560293498, 453.99964483260334)
#   Comparison Star 1: Position (957.999874933312, 576.9999757423182)
#   Comparison Star 2: Position (597.0001110240396, 297.9998062943906)
#   Transit Star: Position (749.0006186473835, 454.0001235281663)
#   Comparison Star 1: Position (958.0000333515482, 576.999895932086)
#   Comparison Star 2: Position (596.9999335752437, 297.9998300584935)
#   Transit Star: Position (749.0001510864398, 453.99976890417975)
#   Comparison Star 1: Position (957.9995376591392, 576.9998523735775)
#   Comparison Star 2: Position (596.9999160078852, 297.9997323794716)
#   Transit Star: Position (749.0001225363777, 453.9998089149642)
#   Comparison Star 1: Position (957.9997781085377, 576.9994809702135)
#   Comparison Star 2: Position (596.9996980484791, 297.99967770941726)
#   Transit Star: Position (749.0001087263371, 453.99992022985396)
#   Comparison Star 1: Position (957.9996035524647, 576.9999032949968)
#   Comparison Star 2: Position (597.0005090464911, 297.99973378407606)
#   Transit Star: Position (749.0002588088303, 453.9994351578941)
#   Comparison Star 1: Position (958.0000576734549, 577.0000133409221)
#   Comparison Star 2: Position (596.9999685675078, 297.9997850322015)
#   Transit Star: Position (749.0002579860367, 453.9996888871693)
#   Comparison Star 1: Position (957.999748236545, 576.9997548179364)
#   Comparison Star 2: Position (597.0002739433247, 297.99949438603426)
#   Transit Star: Position (749.0002108553143, 453.9996234657118)
#   Comparison Star 1: Position (957.9999448502062, 576.9998070993405)
#   Comparison Star 2: Position (596.9999999091106, 298.00011041282454)
#   Transit Star: Position (749.0004779331712, 453.99976344884055)
#   Comparison Star 1: Position (957.9995454802527, 576.9999562195775)
#   Comparison Star 2: Position (597.0003400968085, 297.99963867106925)
#   Transit Star: Position (749.0002879724284, 453.9995332213069)
#   Comparison Star 1: Position (957.9998168615421, 577.0001525431383)
#   Comparison Star 2: Position (597.0001966526653, 297.99976448462377)
#   Transit Star: Position (749.0006158177104, 454.00016626598494)
#   Comparison Star 1: Position (957.9999938141276, 576.9995058648984)
#   Comparison Star 2: Position (596.9999791491185, 297.9997071738578)
#   Transit Star: Position (749.0002059058708, 453.99982667275356)
#   Comparison Star 1: Position (958.0001175968943, 577.0001148439187)
#   Comparison Star 2: Position (596.999891208694, 297.99977645095424)
#   Transit Star: Position (748.9999295919513, 453.9998846089901)
#   Comparison Star 1: Position (957.9996333013978, 577.0003031137741)
#   Comparison Star 2: Position (597.0004356671052, 297.9997349656695)
#   Transit Star: Position (749.0002419020209, 453.9998840146278)
#   Comparison Star 1: Position (957.9999610336735, 576.9998423702017)
#   Comparison Star 2: Position (597.0002541611178, 297.9996707143025)
#   Transit Star: Position (749.0002358259237, 454.00001451199546)
#   Comparison Star 1: Position (957.9997812618486, 576.9999405825403)
#   Comparison Star 2: Position (597.0002933562358, 297.99976281942116)
#   Transit Star: Position (749.0002296132892, 453.9997192277049)
#   Comparison Star 1: Position (957.9994510577299, 576.9997979208597)
#   Comparison Star 2: Position (597.0002403823687, 297.99969133376237)
#   Transit Star: Position (749.0000773712751, 453.99995084968145)
#   Comparison Star 1: Position (957.9999741924587, 576.999692473479)
#   Comparison Star 2: Position (596.9998477250685, 297.9998092061789)
#   Transit Star: Position (749.0000958861107, 454.00000398604936)
#   Comparison Star 1: Position (957.9996573713365, 576.9999766666846)
#   Comparison Star 2: Position (597.0004343723456, 297.9995994672924)
#   Transit Star: Position (749.0004967716885, 453.99974180022303)
#   Comparison Star 1: Position (957.9999187233102, 576.9997085311707)
#   Comparison Star 2: Position (597.0000043128567, 297.99958313071386)
#   Transit Star: Position (748.9998773534422, 453.99993953012813)
#   Comparison Star 1: Position (957.9999373178413, 576.9996190798128)
#   Comparison Star 2: Position (597.000604571757, 297.9997532672899)
#   Transit Star: Position (749.0000324325192, 453.99971473324604)
#   Comparison Star 1: Position (957.9997473545232, 577.0002054622456)
#   Comparison Star 2: Position (597.0004159396543, 297.99969493131067)
#   Transit Star: Position (748.9999255643952, 453.99963607372706)
#   Comparison Star 1: Position (957.9994333159103, 577.0000393974545)
#   Comparison Star 2: Position (597.0000477748162, 298.00017131754186)
#   Transit Star: Position (749.000073713926, 453.99993192852133)
#   Comparison Star 1: Position (957.9998662910011, 576.9999532944395)
#   Comparison Star 2: Position (597.0002401054669, 297.99958352458316)
#   Transit Star: Position (748.9999026258436, 454.00045462769623)
#   Comparison Star 1: Position (957.999744058627, 576.9996886678094)
#   Comparison Star 2: Position (597.0001634423954, 297.99992394888596)
#   Transit Star: Position (749.0000326785569, 453.9999573978621)
#   Comparison Star 1: Position (957.9995230709139, 576.9998291515216)
#   Comparison Star 2: Position (596.9998953378653, 297.99976318559817)
#   Transit Star: Position (749.000212427706, 454.00028666609705)
#   Comparison Star 1: Position (957.9998239516007, 577.0000644820607)
#   Comparison Star 2: Position (596.9999723392847, 297.9991994104287)
#   Transit Star: Position (749.0000454853977, 453.9996393628726)
#   Comparison Star 1: Position (957.9992692117958, 576.9998812872122)
#   Comparison Star 2: Position (597.0004244198703, 297.9994179710677)
#   Transit Star: Position (749.0001191717395, 453.9998702778271)
#   Comparison Star 1: Position (957.9997490754904, 576.9998536038067)
#   Comparison Star 2: Position (597.0001179520083, 297.99965000001674)
#   Transit Star: Position (749.0002174215188, 454.00009857020564)
#   Comparison Star 1: Position (957.9999142076002, 576.99977684745)
#   Comparison Star 2: Position (596.999903259219, 297.99974688493995)
#   Transit Star: Position (748.9998577872889, 454.0002775155358)
#   Comparison Star 1: Position (957.9998188043569, 576.99952826496)
#   Comparison Star 2: Position (597.0000243262753, 297.99992607902647)
#   Transit Star: Position (749.000111931117, 454.00025808682216)
#   Comparison Star 1: Position (957.9998807970355, 576.9998151165661)
#   Comparison Star 2: Position (597.0000073714777, 297.99925361832425)
#   Transit Star: Position (749.0000301350465, 453.9998174318634)
#   Comparison Star 1: Position (957.9994100737554, 576.9999729939061)
#   Comparison Star 2: Position (597.0001659189242, 298.00001792293716)
#   Transit Star: Position (749.0002713949509, 454.0002347291381)
#   Comparison Star 1: Position (957.9997385986866, 576.9999052730855)
#   Comparison Star 2: Position (597.0002174247226, 297.99985677471807)
#   Transit Star: Position (749.0001891500848, 454.0001586321448)
#   Comparison Star 1: Position (957.9999784824016, 577.0000053579871)
#   Comparison Star 2: Position (597.000224460123, 297.99947078724546)
#   Transit Star: Position (748.999957361011, 453.99974034679576)
#   Comparison Star 1: Position (958.0000916931855, 577.0003206319383)
#   Comparison Star 2: Position (597.0001715162251, 298.00042970693613)
#   Transit Star: Position (748.999815713816, 454.0000508226902)
#   Comparison Star 1: Position (957.999783109619, 577.0000849228653)
# ...
#   Transit Star: Position (749.0001773603493, 453.99991023129274)
#   Comparison Star 1: Position (957.9995866364736, 576.9999735803783)
#   Comparison Star 2: Position (596.9997557223509, 297.9995620571087)
#   Transit Star: Position (748.9998622491631, 453.9997683038791)
#   Comparison Star 1: Position (957.9993464265317, 577.0000324545456)
#   Comparison Star 2: Position (597.0002187248783, 297.9999040510428)
#   Transit Star: Position (748.99965198853, 454.00024753926306)
#   Comparison Star 1: Position (957.9994042639682, 577.0000225079713)
#   Comparison Star 2: Position (597.0002596654145, 297.9994757495438)
#   Transit Star: Position (749.000080257762, 453.99989503954237)
#   Comparison Star 1: Position (957.9997940897649, 576.9999669475042)
#   Comparison Star 2: Position (597.0000831940953, 298.0000224437619)
#   Transit Star: Position (749.0001040495055, 454.000003394754)
#   Comparison Star 1: Position (957.9993489153636, 576.9997113257807)
#   Comparison Star 2: Position (597.000135856258, 297.99978655649755)
#   Transit Star: Position (749.0002629129336, 453.9997168257923)
#   Comparison Star 1: Position (957.999574976268, 577.0003412591611)
#   Comparison Star 2: Position (597.0001995584821, 297.99956858064587)
#   Transit Star: Position (749.0004659934422, 454.00008398103654)
#   Comparison Star 1: Position (957.9994446060006, 577.0000164765416)
#   Comparison Star 2: Position (597.0003615387752, 297.99983979085454)
#   Transit Star: Position (748.9998097455563, 454.0001752732858)
#   Comparison Star 1: Position (957.9993087888049, 576.9996573349033)
#   Comparison Star 2: Position (597.000456214944, 298.0000092786247)
#   Transit Star: Position (749.0001217627445, 453.99996317702124)
#   Comparison Star 1: Position (957.9994571045067, 577.0001186967471)
#   Comparison Star 2: Position (597.0003483385889, 297.9998063687494)
#   Transit Star: Position (748.9997393125374, 453.9995477745363)
#   Comparison Star 1: Position (957.9994380632256, 576.9998904585701)
#   Comparison Star 2: Position (597.0001296368124, 297.9996959236381)
#   Transit Star: Position (749.0001623782318, 454.00024054508407)
#   Comparison Star 1: Position (957.9991038638751, 577.0000194595502)
#   Comparison Star 2: Position (597.0004055545783, 297.999648226653)
#   Transit Star: Position (748.9999723044364, 453.99968070779227)
#   Comparison Star 1: Position (957.9995918981338, 576.9999109949987)
#   Comparison Star 2: Position (596.9999271072802, 297.9998433562067)
#   Transit Star: Position (749.0003637675604, 453.9997735029469)
#   Comparison Star 1: Position (957.9998245300711, 577.000056744464)
#   Comparison Star 2: Position (597.0000007367862, 297.9997896818576)
#   Transit Star: Position (748.9994573904374, 453.99977724398315)
#   Comparison Star 1: Position (957.9992859451786, 576.9997815445299)
#   Comparison Star 2: Position (597.0002977016129, 297.9998179616575)
#   Transit Star: Position (748.9999325297927, 453.9998869327398)
#   Comparison Star 1: Position (957.9991934277886, 576.9999154456751)
#   Comparison Star 2: Position (597.0000698449021, 297.99991708385477)
#   Transit Star: Position (748.9996873458671, 453.9998808610445)
#   Comparison Star 1: Position (957.9996141305147, 576.999626872348)
#   Comparison Star 2: Position (597.0001814460368, 297.99977561682437)
#   Transit Star: Position (749.0000182807407, 454.0001631810721)
#   Comparison Star 1: Position (957.9996123558526, 576.9998866846944)
#   Comparison Star 2: Position (597.000375422633, 297.99968695548506)
#   Transit Star: Position (749.0000845131038, 453.9998064848121)
#   Comparison Star 1: Position (957.9992275936577, 576.9996362130801)
#   Comparison Star 2: Position (596.9997544468872, 297.999907911828)
#   Transit Star: Position (748.9997939228754, 454.00009948642)
#   Comparison Star 1: Position (957.9991674762879, 577.0001681970166)
#   Comparison Star 2: Position (597.0000556849792, 298.00011757107404)
#   Transit Star: Position (749.0003286815329, 454.0003144583925)
#   Comparison Star 1: Position (957.9992438250691, 577.0000677517152)
#   Comparison Star 2: Position (597.0002733682852, 297.99981929735236)
#   Transit Star: Position (748.9998781093861, 453.9994726590094)
#   Comparison Star 1: Position (957.9994146478859, 577.00004114554)
#   Comparison Star 2: Position (597.0001446761602, 297.999862193448)
#   Transit Star: Position (748.9999746328598, 453.99987946960925)
#   Comparison Star 1: Position (957.9995643124669, 576.9998837391688)
#   Comparison Star 2: Position (596.9998952310347, 298.00013636661345)
#   Transit Star: Position (748.9999887437339, 454.00029250359756)
#   Comparison Star 1: Position (957.9994837217631, 577.000108849214)
#   Comparison Star 2: Position (597.0002054286406, 297.99977912104896)
#   Transit Star: Position (748.9993440149702, 454.0002182456272)
#   Comparison Star 1: Position (957.9995211507384, 577.0000362411502)
#   Comparison Star 2: Position (597.0002861516552, 297.99978856862083)
#   Transit Star: Position (748.9997979006163, 454.0000327114862)
#   Comparison Star 1: Position (957.999377995713, 576.9999053005392)
#   Comparison Star 2: Position (596.99992250219, 297.9997819957606)
#   Transit Star: Position (748.9995444532877, 453.99987025868023)
#   Comparison Star 1: Position (957.9993102940027, 577.0001488384239)
#   Comparison Star 2: Position (597.0001271760141, 297.9999286478933)
#   Transit Star: Position (748.9998985038369, 453.9998185090342)
#   Comparison Star 1: Position (957.9989253439167, 576.9997802875765)
#   Comparison Star 2: Position (597.000204179997, 297.99995853719093)
#   Transit Star: Position (749.0000207038819, 453.99965294816894)
#   Comparison Star 1: Position (957.9993208730101, 577.0000206089217)
#   Comparison Star 2: Position (596.9999008614193, 298.00016390256735)
#   Transit Star: Position (748.9998701707491, 454.00042131630676)
#   Comparison Star 1: Position (957.9996935669133, 576.9998587913025)
#   Comparison Star 2: Position (596.9999972188613, 298.0003844631672)
#   Transit Star: Position (749.0001528206337, 453.99979116063037)
#   Comparison Star 1: Position (957.9995666134092, 576.9997496357486)
#   Comparison Star 2: Position (597.0001545770989, 298.000040114929)
#   Transit Star: Position (749.0001711333736, 453.9999603481537)
#   Comparison Star 1: Position (957.9993093074422, 576.9998788524856)
#   Comparison Star 2: Position (596.9999128192909, 297.9998389234539)
#   Transit Star: Position (748.9997697615531, 454.0003484920475)
#   Comparison Star 1: Position (957.9994150293718, 577.0000781143045)
#   Comparison Star 2: Position (597.0003410244615, 297.9995617622974)
#   Transit Star: Position (749.0001191324337, 454.00021975695284)
#   Comparison Star 1: Position (957.9993100790191, 577.0001204280164)
#   Comparison Star 2: Position (597.0003664487558, 298.0001185444435)
#   Transit Star: Position (749.0000911508092, 453.99996951636837)
#   Comparison Star 1: Position (957.9992251861232, 576.9999920190976)
#   Comparison Star 2: Position (597.0001052073967, 297.99959879265185)
#   Transit Star: Position (748.9998883933872, 454.0002225924737)
#   Comparison Star 1: Position (957.999526195342, 576.999510128247)
#   Comparison Star 2: Position (596.9998916603827, 297.99980981572435)
#   Transit Star: Position (749.0001069498223, 454.00005218566184)
#   Comparison Star 1: Position (957.9991532764489, 576.9999954142695)
#   Comparison Star 2: Position (597.0000275012837, 298.00023195401343)
#   Transit Star: Position (749.000076963681, 453.9997307793608)
#   Comparison Star 1: Position (957.9996159259807, 576.9998252865112)
#   Comparison Star 2: Position (596.999978796607, 297.9999045675739)
#   Transit Star: Position (748.9996700456936, 453.9999811472575)
#   Comparison Star 1: Position (957.999489517167, 577.0000654949487)
#   Comparison Star 2: Position (597.0003737228797, 297.99973204534353)
#   Transit Star: Position (748.9996046105659, 453.9999916261074)
#   Comparison Star 1: Position (957.9990115036529, 577.0000364454362)
#   Comparison Star 2: Position (596.9999930226681, 297.99992808847793)
#   Transit Star: Position (749.0000546280816, 453.99968568539094)
#   Comparison Star 1: Position (957.9990456517155, 576.9999322282746)
#   Comparison Star 2: Position (597.0000673676144, 297.99993481439463)
#   Transit Star: Position (748.9998507924278, 454.000161131651)
#   Comparison Star 1: Position (957.9992405026908, 577.0004680530665)
#   Comparison Star 2: Position (596.9999470529635, 297.9998867611386)
#   Transit Star: Position (748.999858862123, 453.9998468736738)
#   Comparison Star 1: Position (957.9991010766095, 576.9998592896263)
#   Comparison Star 2: Position (597.0001838131711, 298.0001299112511)
#   Transit Star: Position (748.9999207632567, 454.0003656526551)
#   Comparison Star 1: Position (957.9993956396148, 576.9998886781608)
#   Comparison Star 2: Position (597.0002009282267, 297.99980622338546)
#   Transit Star: Position (748.9996965020863, 453.9998526643204)
#   Comparison Star 1: Position (957.9992493050563, 577.0001204770533)
#   Comparison Star 2: Position (596.9999642451942, 297.99968470947067)
#   Transit Star: Position (748.9997882698663, 453.9999256096376)
#   Comparison Star 1: Position (957.9993585821164, 577.0002360219464)
#   Comparison Star 2: Position (597.0000443854109, 297.99991122160753)
#   Transit Star: Position (749.0000614341742, 453.99994790155085)
#   Comparison Star 1: Position (957.9994474982874, 577.0001382762242)
#   Comparison Star 2: Position (597.0000188606889, 297.9999034078728)
#   Transit Star: Position (749.0000209635729, 453.99986900008577)
#   Comparison Star 1: Position (957.9990393922914, 577.0005813684672)
#   Comparison Star 2: Position (597.0002857724023, 297.9999286174089)
#   Transit Star: Position (749.0001265550866, 453.99972154371903)
#   Comparison Star 1: Position (957.9991953125733, 577.0000523671957)
#   Comparison Star 2: Position (596.999883103179, 297.99974975736535)
#   Transit Star: Position (748.9997666511547, 454.0000151529787)
#   Comparison Star 1: Position (957.9989704710104, 576.9998699786358)
#   Comparison Star 2: Position (597.0002368892293, 297.9999966125497)
#   Transit Star: Position (749.0000738052157, 453.99969370778194)
#   Comparison Star 1: Position (957.9990489177978, 576.9997277520848)
#   Comparison Star 2: Position (597.0003075346418, 298.00003888197307)
#   Transit Star: Position (748.9997530713804, 454.0003755982628)
#   Comparison Star 1: Position (957.9989003482214, 576.9998012478375)
#   Comparison Star 2: Position (597.000199498866, 297.99947300540003)
#   Transit Star: Position (748.999760563378, 454.0002054058854)
#   Comparison Star 1: Position (957.9987548712452, 577.0001007742298)
#   Comparison Star 2: Position (597.0000713157875, 297.9999687522599)
#   Transit Star: Position (748.9999367393257, 454.00017382126987)
#   Comparison Star 1: Position (957.9987760962076, 577.0000473457487)
#   Comparison Star 2: Position (597.0003630672538, 297.9999253525636)
#   Transit Star: Position (748.9998164424952, 453.99998523859813)
#   Comparison Star 1: Position (957.9986632434476, 577.0002378502251)
#   Comparison Star 2: Position (597.0004434379964, 298.00027377599116)
#   Transit Star: Position (748.999277546168, 454.0002641826941)
#   Comparison Star 1: Position (957.9990333026873, 576.9999428612373)
#   Comparison Star 2: Position (596.9998679623782, 297.99979781125217)
#   Transit Star: Position (748.9996811855286, 454.0000103610098)
#   Comparison Star 1: Position (957.9990252097116, 576.9997887553042)
#   Comparison Star 2: Position (597.0003710700753, 298.000010079871)
#   Transit Star: Position (749.0000830066297, 454.000372535166)
#   Comparison Star 1: Position (957.9989643061938, 577.000138000471)
#   Comparison Star 2: Position (596.999559448584, 298.00001949352725)
#   Transit Star: Position (748.9995348480887, 453.9996416467787)
#   Comparison Star 1: Position (957.9984102259375, 577.0000628371699)
#   Comparison Star 2: Position (596.9998104300392, 297.9999667711346)
#   Transit Star: Position (748.9995870009742, 454.0004035617443)
#   Comparison Star 1: Position (957.9991821447028, 577.0001802198897)
#   Comparison Star 2: Position (597.000045504326, 298.0004619186535)
#   Transit Star: Position (748.9997350806623, 454.00046782426494)
#   Comparison Star 1: Position (957.9985250118928, 577.0000102451288)
#   Comparison Star 2: Position (597.0002898658778, 298.0001307869455)
#   Transit Star: Position (748.9999798809696, 454.00023586753707)
#   Comparison Star 1: Position (957.9986082456355, 577.0001470615191)
#   Comparison Star 2: Position (596.9997435414614, 298.0000770027123)
#   Transit Star: Position (748.99985597824, 454.00003418804)
#   Comparison Star 1: Position (957.9982991345331, 576.9998186819337)
#   Comparison Star 2: Position (596.9998830216817, 298.00053328043856)
#   Transit Star: Position (748.9995844101223, 453.9999469928159)
#   Comparison Star 1: Position (957.9985822503872, 577.0000306627965)
#   Comparison Star 2: Position (597.0002056534383, 298.0001097569041)
#   Transit Star: Position (748.9996261366032, 453.9997789937513)
#   Comparison Star 1: Position (957.9982965447508, 577.000444643302)
#   Comparison Star 2: Position (597.0002888201011, 298.0000484697985)
#   Transit Star: Position (748.9998773374042, 453.9999841069438)
#   Comparison Star 1: Position (957.9984350389992, 577.0000372659945)
#   Comparison Star 2: Position (596.9996780221198, 297.9993917127135)
#   Transit Star: Position (748.999686764796, 453.99965819646195)
#   Comparison Star 1: Position (957.9981795658748, 577.0000266076667)
#   Comparison Star 2: Position (596.9998515735589, 297.99986973329914)
#   Transit Star: Position (749.0002239015008, 454.00011854356705)
#   Comparison Star 1: Position (957.9983663134307, 577.000067726043)
#   Comparison Star 2: Position (596.9996992982556, 297.9999747234266)
#   Transit Star: Position (748.9997948835133, 453.99981239363217)
#   Comparison Star 1: Position (957.998175980274, 577.0000656334257)
#   Comparison Star 2: Position (596.9999803975753, 298.0000944404485)
#   Transit Star: Position (748.9996143789936, 454.0001042809753)
#   Comparison Star 1: Position (957.9984023794318, 576.9997081685766)
#   Comparison Star 2: Position (596.9997399906966, 297.99945807634134)
#   Transit Star: Position (748.9996483813636, 453.99979973178796)
#   Comparison Star 1: Position (957.9984601073642, 576.9999978216421)
#   Comparison Star 2: Position (596.9996738909939, 298.00035420714977)
#   Transit Star: Position (748.9999530894609, 454.000378012833)
#   Comparison Star 1: Position (957.998111241987, 576.9997961051253)
#   Comparison Star 2: Position (596.999715714595, 298.0000209387774)
#   Transit Star: Position (748.9995665070229, 453.99991361621716)
#   Comparison Star 1: Position (957.998184603142, 577.0000716083118)
#   Comparison Star 2: Position (596.9996536445364, 297.99960122506957)
#   Transit Star: Position (748.9993833254032, 453.99984091713293)
#   Comparison Star 1: Position (957.997648923831, 577.0001500378036)
#   Comparison Star 2: Position (596.9997699976818, 297.99979564300725)
#   Transit Star: Position (749.0000293051701, 453.9999761827428)
#   Comparison Star 1: Position (957.9978886302574, 577.0001423112587)
#   Comparison Star 2: Position (596.999680115406, 297.99986175514766)
#   Transit Star: Position (748.9997413749883, 453.9999815743493)
#   Comparison Star 1: Position (957.998368582332, 577.0004602753279)
#   Comparison Star 2: Position (597.0002107404031, 297.9999996979516)
#   Transit Star: Position (748.9995264256821, 454.0002629977476)
#   Comparison Star 1: Position (957.9980004667165, 576.9999015882094)
#   Comparison Star 2: Position (597.0004581655013, 298.00000338516963)
#   Transit Star: Position (748.9999707445604, 454.00021340314515)
#   Comparison Star 1: Position (957.9982263213861, 577.0001892658643)
#   Comparison Star 2: Position (596.9999685259747, 297.9998918847312)
#   Transit Star: Position (748.9998001345108, 453.99992665346036)
#   Comparison Star 1: Position (957.9978150253183, 577.0004055630852)
#   Comparison Star 2: Position (596.9998877559985, 298.0003287705501)
#   Transit Star: Position (748.9996189332876, 453.9999418422425)
#   Comparison Star 1: Position (957.9977338386288, 577.0001750932219)
#   Comparison Star 2: Position (597.0001016266503, 298.00024238138167)

# %% [markdown]
# <h2 style="color: skyblue;" id="Differential-Photometry">Section 6: Differential Photometry</h2>
# <p>
# </p>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from datetime import datetime
from photutils.aperture import CircularAperture, aperture_photometry
from astropy.stats import sigma_clip
from scipy.signal import savgol_filter
import george
from george import kernels
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Perform aperture photometry
def perform_aperture_photometry(image_data, positions, aperture_radius=5):
    """Perform aperture photometry on given positions in the image data."""
    apertures = CircularAperture(positions, r=aperture_radius)
    phot_table = aperture_photometry(image_data, apertures)
    fluxes = phot_table['aperture_sum']
    return fluxes

# Plot stars on the image
def plot_stars(image_data, recentered_positions, aperture_radius=5):
    """Plot target and comparison stars on the image."""
    plt.figure(figsize=(10, 10))
    plt.imshow(image_data, cmap='gray', origin='lower', vmin=np.percentile(image_data, 5), vmax=np.percentile(image_data, 95))
    apertures = CircularAperture(recentered_positions, r=aperture_radius)
    apertures.plot(color='red', lw=1.5, alpha=0.7)
    
    for i, pos in enumerate(recentered_positions):
        label = 'Target' if i == 0 else f'Comp {i}'
        plt.text(pos[0], pos[1], label, color='yellow', fontsize=12)
    
    plt.title('Transit and Comparison Stars')
    plt.xlabel('X Pixel')
    plt.ylabel('Y Pixel')
    plt.grid(True)
    plt.show()

# Plot brightness curves
def plot_brightness_curves(times, target_fluxes, comparison_fluxes):
    """Plot the brightness curves of the target and comparison stars."""
    plt.figure(figsize=(10, 6))
    plt.plot(times, target_fluxes, marker='o', linestyle='-', color='b', label='Target Star')
    
    for j, comp_flux in enumerate(comparison_fluxes):
        plt.plot(times, comp_flux, marker='o', linestyle='-', label=f'Comparison Star {j+1}')
    
    plt.xlabel('Time')
    plt.ylabel('Flux')
    plt.title('Brightness Curves')
    plt.legend()
    plt.grid(True)
    plt.gcf().autofmt_xdate()
    plt.tight_layout()
    plt.show()

# Calculate weighted average of comparison star fluxes
def weighted_average_comparison_fluxes(comparison_fluxes):
    """Calculate the weighted average of comparison star fluxes."""
    weights = [1 / np.var(flux) for flux in comparison_fluxes]
    weighted_fluxes = np.average(comparison_fluxes, axis=0, weights=weights)
    return weighted_fluxes

# Perform Gaussian Process Regression for noise removal
def apply_gaussian_process(times, flux):
    """Apply Gaussian Process Regression to remove noise from flux data."""
    times = np.array(times)
    kernel = kernels.Matern32Kernel(np.var(flux))
    gp = george.GP(kernel)
    gp.compute(times)
    mu, _ = gp.predict(flux, times, return_var=True)
    return mu

# Differential photometry
def differential_photometry(folder_path, keyword, recentered_positions, aperture_radius=5):
    """Perform differential photometry to detect exoplanet transits."""
    times = []
    target_fluxes = []
    comparison_fluxes = [[] for _ in range(len(recentered_positions[0]) - 1)]
    
    for i, filename in enumerate(sorted(os.listdir(folder_path))):
        if keyword in filename:
            file_path = os.path.join(folder_path, filename)
            try:
                with fits.open(file_path) as hdul:
                    image_data = hdul[0].data
                    header = hdul[0].header
                    time = datetime.strptime(header['DATE-OBS'], '%Y-%m-%dT%H:%M:%S.%f')
                    times.append(time)

                    if i == 0:
                        plot_stars(image_data, recentered_positions[i], aperture_radius)

                    target_flux = perform_aperture_photometry(image_data, [recentered_positions[i][0]], aperture_radius=aperture_radius)[0]
                    target_fluxes.append(target_flux)

                    for j in range(len(comparison_fluxes)):
                        comp_flux = perform_aperture_photometry(image_data, [recentered_positions[i][j+1]], aperture_radius=aperture_radius)[0]
                        comparison_fluxes[j].append(comp_flux)
            except Exception as e:
                logging.error(f"Error processing file {file_path}: {e}")
    
    # Sigma clipping to remove outliers
    target_fluxes = sigma_clip(target_fluxes, sigma=3, maxiters=2)
    for j in range(len(comparison_fluxes)):
        comparison_fluxes[j] = sigma_clip(comparison_fluxes[j], sigma=3, maxiters=2)
    
    plot_brightness_curves(times, target_fluxes, comparison_fluxes)
    
    times_num = np.array([datetime.timestamp(t) for t in times])
    
    weighted_comparison_flux = weighted_average_comparison_fluxes([flux.data for flux in comparison_fluxes])
    normalized_flux = np.array(target_fluxes.data) / weighted_comparison_flux

    median_filtered_flux = savgol_filter(normalized_flux, window_length=11, polyorder=2)
    clipped_flux = sigma_clip(median_filtered_flux, sigma=3, maxiters=2)
    
    cleaned_flux = apply_gaussian_process(times_num, clipped_flux)

    plt.figure(figsize=(10, 6))
    plt.plot(times, normalized_flux, marker='o', linestyle='-', color='b', label='Normalized Flux')
    plt.plot(times, cleaned_flux, linestyle='-', color='r', label='GP Cleaned Flux')
    plt.xlabel('Time')
    plt.ylabel('Normalized Flux')
    plt.title('Differential Light Curve')
    plt.legend()
    plt.grid(True)
    plt.gcf().autofmt_xdate()
    plt.tight_layout()
    plt.show()

# Example usage
# folder = "D:\\TransitResearch\\2024-05-31\\calibrated_images"
# keyword = "HAT"
# recentered_positions = recenter_stars(folder, keyword, initial_positions, box_size=aperture_size)

differential_photometry(folder, keyword, recentered_positions)

# %% [markdown]
# <h2 style="color: skyblue;" id="plotting-transit-brightness">Section 7: Plotting Transit</h2>
# <p>
# </p>

# %% [markdown]
# <h2 style="color: skyblue;" id="estimating-exoplanet-information">Section 8: Estimating Exoplanet Information</h2>
# <p>
# </p>
